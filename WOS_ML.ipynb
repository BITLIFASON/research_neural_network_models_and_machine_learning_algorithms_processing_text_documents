# %% [markdown]
# # IMPORT, CONFIG

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt

import gensim
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import catboost
from catboost import CatBoostClassifier

import lightgbm
from lightgbm import LGBMClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import time
import math
import random
import pickle
import re
from collections import Counter

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Programs\miniconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 8, 6

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # LOAD

# %%
X = list()
with open('..\\datasets\\WOS\\WOS46985\\X.txt','r') as X_file:
    lines = X_file.readlines()
    for line in lines:
        X.append(line.strip())

# %%
Y = list()
with open('..\\datasets\\WOS\\WOS46985\\Y.txt','r') as Y_file:
    lines = Y_file.readlines()
    for line in lines:
        Y.append(line.strip())

# %%
YL1 = list()
with open('..\\datasets\\WOS\\WOS46985\\YL1.txt','r') as YL1_file:
    lines = YL1_file.readlines()
    for line in lines:
        YL1.append(line.strip())

# %%
YL2 = list()
with open('..\\datasets\\WOS\\WOS46985\\YL2.txt','r') as YL2_file:
    lines = YL2_file.readlines()
    for line in lines:
        YL2.append(line.strip())

# %%
source = pd.DataFrame({'texts':pd.Series(X, dtype='object').apply(lambda x: re.sub('[^A-Za-z0-9 ]+', '', x)),
 'Y':pd.Series(Y, dtype='float'),
 'YL1':pd.Series(YL1, dtype='float'),
 'YL2':pd.Series(YL2, dtype='float')})
source = source.astype({'Y': int, 'YL1': int, 'YL2':int})

# %%
source
# Out:
#                                                    texts    Y  YL1  YL2
# 0      2  1dimensional nonlinear optical waves throug...   12    0   12
# 1      betaamyloid A beta and tau pathology become in...   74    5    2
# 2      Decreasing of energy consumption and environme...   68    4    7
# 3      Hybrid electric vehicles are assumed to play a...   26    1   10
# 4      L34Dihydroxyphenylalanine LDOPA remains the pr...  115    5   43
# ...                                                  ...  ...  ...  ...
# 46980  Zusammenfassung Hintergrund Karate erfreut sic...  122    5   50
# 46981  ZWave is an implementation of home automation ...   15    0   15
# 46982  Zwitterionic peptides were anchored to a condu...  110    5   38
# 46983  ZY3 has been acquiring high quality imagery si...   10    0   10
# 46984  Zymoseptoria tritici the causal agent of septo...  125    6    0
#
# [46985 rows x 4 columns]

# %%
source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46985 entries, 0 to 46984
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   texts   46985 non-null  object
#  1   Y       46985 non-null  int32
#  2   YL1     46985 non-null  int32
#  3   YL2     46985 non-null  int32
# dtypes: int32(3), object(1)
# memory usage: 917.8+ KB

# %%
del X, Y, YL1, YL2 #,tokens

# %%
target_column = 'YL1'
data = source[['texts',target_column]] # source source[source['YL1']==0]

# %%
data
# Out:
#                                                    texts  YL1
# 0      2  1dimensional nonlinear optical waves throug...    0
# 1      betaamyloid A beta and tau pathology become in...    5
# 2      Decreasing of energy consumption and environme...    4
# 3      Hybrid electric vehicles are assumed to play a...    1
# 4      L34Dihydroxyphenylalanine LDOPA remains the pr...    5
# ...                                                  ...  ...
# 46980  Zusammenfassung Hintergrund Karate erfreut sic...    5
# 46981  ZWave is an implementation of home automation ...    0
# 46982  Zwitterionic peptides were anchored to a condu...    5
# 46983  ZY3 has been acquiring high quality imagery si...    0
# 46984  Zymoseptoria tritici the causal agent of septo...    6
#
# [46985 rows x 2 columns]

# %%
train_df, test_df = train_test_split(data, test_size=0.33, random_state=RANDOM_SEED,stratify=data[target_column].to_list())

# %%
len(train_df), len(test_df)
# Out:
# (31479, 15506)

# %% [markdown]
# # PROCESSING

# %% [markdown]
# ## PROBLEMS PROCESSING

# %% [markdown]
# ---

# %% [markdown]
# проблема ",background", 45 символов в скобках, (2 + 1)-dimensional, (D)ecreasing, (L)-3,4-Dihydroxyphenylalanine ((L)-DOPA)

# %% [markdown]
# \s*(\(.{0,30}\))\s* для убирания отдельных слов в скобках; они являются group match [надо доработать с пред и пост условиями]

# %% [markdown]
# in tokens .replace("[,.]", "")

# %% [markdown]
# \s*(\(.{0,5}\))\S+\s* для проблем типо (D)ecreasing (D) является group match [надо доработать с пред и пост условиями]

# %% [markdown]
# ---

# %%
EMBEDDING_SIZE = 300
EMBEDDING_SIZE
# Out:
# 300

# %%
class MyTokenizer():
    class Encoding:
        def __init__(self):
            super().__init__()
            tokens = list()
            ids = list()

    def __init__(self):
        self.index2token = list()
        self.token2index = dict()
        self.token2count = Counter()
        self.encoding = MyTokenizer.Encoding()
        self.reset()

    def add_sentence(self, sentence):
        for token in self.encode(sentence).tokens:
            self.add_token(token)

    def add_token(self, token):
        if token not in self.token2index:
            self.token2index[token] = len(self.index2token)
            self.token2count[token] += 1
            self.index2token.append(token)
        else:
            self.token2count[token] += 1
    
    def has_token(self, token) -> bool:
        return token in self.token2index

    def add_texts(self):
        sents_texts = train_df.texts.to_list()
        for sent in sents_texts:
            self.add_sentence(sent)

    def token_to_id(self, token):
        if token in self.token2index:
            return self.token2index[token]
        else:    # убрал паддинг - если нет слова в словаре то пропуск
            pass

    def id_to_token(self, id_):
        if id_ in self.index2token:
            return self.index2token[id_]
        else:    # убрал отсутсвие id в словаре - если нет id в словаре то пропуск
            pass
    
    def is_empty(self):
        empty_size = 4
        return self.size() <= empty_size

    def shrink(self, n):
        # для сокращения словаря (выбирает n самых частых слов) (подаётся n)
        best_tokens = self.token2count.most_common(n)
        self.reset()
        for token, count in best_tokens:
            self.add_token(token)
            self.token2count[token] = count

    def reset(self):
        self.token2count = Counter()
        self.index2token = []
        self.token2index = {token: index for index, token in enumerate(self.index2token)}

    def get_vocab(self):
        return self.token2index
    
    def get_vocab_size(self):
        return len(self.index2token)
        
    def encode(self, text: str): # sentence: str, max_length: int
        text = text.lower().strip()
        self.encoding.tokens = text.split(' ')
        self.encoding.tokens = [token for token in self.encoding.tokens]
        return self.encoding

    def decode(self, ids):
        return print([self.index2token[id_] for id_ in ids].join(' '))

# %%
tokenizer = MyTokenizer()

# %%
tokenizer.add_texts()

# %%
tokenizer.token2index
# Out:
# {'the': 0,
#  'article': 1,
#  'acquaints': 2,
#  'with': 3,
#  'means': 4,
#  'of': 5,
#  'dramatherapeutic': 6,
#  'intervention': 7,
#  'in': 8,
#  'two': 9,
#  'addictions': 10,
#  'departments': 11,
#  '': 12,
#  'centre': 13,
#  'for': 14,
#  'secondary': 15,
#  'prevention': 16,
#  'and': 17,
#  'addiction': 18,
#  'treatment': 19,
#  'at': 20,
#  'military': 21,
#  'hospital': 22,
#  'olomouc': 23,
#  'toxicorehabilitation': 24,
#  'department': 25,
#  'psychiatric': 26,
#  'kromeriz': 27,
#  'first': 28,
#  'runs': 29,
#  'a': 30,
#  'detoxification': 31,
#  'shortterm': 32,
#  'one': 33,
#  'month': 34,
#  'programme': 35,
#  'while': 36,
#  'mandala': 37,
#  'mediumterm': 38,
#  'as': 39,
#  'long': 40,
#  'half': 41,
#  'year': 42,
#  'is': 43,
#  'being': 44,
#  'implemented': 45,
#  'second': 46,
#  'part': 47,
#  'text': 48,
#  'presents': 49,
#  'results': 50,
#  'an': 51,
#  'enquiry': 52,
#  'focused': 53,
#  'on': 54,
#  'tracing': 55,
#  'differences': 56,
#  'connections': 57,
#  'between': 58,
#  'clients': 59,
#  'perception': 60,
#  'benefits': 61,
#  'overall': 62,
#  'concept': 63,
#  'above': 64,
#  'said': 65,
#  'implementation': 66,
#  'questionnaire': 67,
#  'method': 68,
#  'did': 69,
#  'not': 70,
#  'reveal': 71,
#  'evaluations': 72,
#  'both': 73,
#  'key': 74,
#  'factors': 75,
#  'dambreak': 76,
#  'modeling': 77,
#  'are': 78,
#  'accuracy': 79,
#  'speed': 80,
#  'therefore': 81,
#  'highperformance': 82,
#  'calculations': 83,
#  'great': 84,
#  'importance': 85,
#  'to': 86,
#  'simulation': 87,
#  'events': 88,
#  'this': 89,
#  'study': 90,
#  'we': 91,
#  'develop': 92,
#  'twodimensional': 93,
#  'hydrodynamic': 94,
#  'model': 95,
#  'based': 96,
#  'finite': 97,
#  'volume': 98,
#  'simulate': 99,
#  'flow': 100,
#  'routing': 101,
#  'process': 102,
#  'roes': 103,
#  'approximate': 104,
#  'riemann': 105,
#  'solution': 106,
#  'adopted': 107,
#  'solve': 108,
#  'interface': 109,
#  'flux': 110,
#  'grid': 111,
#  'cells': 112,
#  'accurately': 113,
#  'discontinuous': 114,
#  'graphics': 115,
#  'processing': 116,
#  'unit': 117,
#  'gpubased': 118,
#  'parallel': 119,
#  'openacc': 120,
#  'used': 121,
#  'realize': 122,
#  'computing': 123,
#  'because': 124,
#  'explicit': 125,
#  'discrete': 126,
#  'technique': 127,
#  'governing': 128,
#  'equations': 129,
#  'there': 130,
#  'no': 131,
#  'correlation': 132,
#  'single': 133,
#  'time': 134,
#  'step': 135,
#  'can': 136,
#  'be': 137,
#  'easily': 138,
#  'realized': 139,
#  'by': 140,
#  'adding': 141,
#  'directives': 142,
#  'loop': 143,
#  'structure': 144,
#  'analyze': 145,
#  'performance': 146,
#  'considered': 147,
#  'pangtoupao': 148,
#  'flood': 149,
#  'storage': 150,
#  'area': 151,
#  'china': 152,
#  'using': 153,
#  'nvidia': 154,
#  'tesla': 155,
#  'k20c': 156,
#  'card': 157,
#  'four': 158,
#  'different': 159,
#  'division': 160,
#  'schemes': 161,
#  'carefully': 162,
#  'studying': 163,
#  'optimization': 164,
#  'data': 165,
#  'transportation': 166,
#  'algorithm': 167,
#  'speedup': 168,
#  'factor': 169,
#  '2070': 170,
#  'achieved': 171,
#  'acceleration': 172,
#  'better': 173,
#  'than': 174,
#  'that': 175,
#  'openmp': 176,
#  '16kernel': 177,
#  'computer': 178,
#  'further': 179,
#  'analysis': 180,
#  'reveals': 181,
#  'models': 182,
#  'involving': 183,
#  'larger': 184,
#  'number': 185,
#  'exhibit': 186,
#  'greater': 187,
#  'efficiency': 188,
#  'higher': 189,
#  'rate': 190,
#  'addition': 191,
#  'mode': 192,
#  'has': 193,
#  'good': 194,
#  'portability': 195,
#  'making': 196,
#  'it': 197,
#  'easy': 198,
#  'computation': 199,
#  'from': 200,
#  'original': 201,
#  'serial': 202,
#  'advantages': 203,
#  'high': 204,
#  'available': 205,
#  'required': 206,
#  'hardware': 207,
#  'c': 208,
#  '2016': 209,
#  'american': 210,
#  'society': 211,
#  'civil': 212,
#  'engineers': 213,
#  'mental': 214,
#  'health': 215,
#  'issues': 216,
#  'have': 217,
#  'been': 218,
#  'increasingly': 219,
#  'recognized': 220,
#  'public': 221,
#  'problems': 222,
#  'globally': 223,
#  'their': 224,
#  'burden': 225,
#  'projected': 226,
#  'increase': 227,
#  'over': 228,
#  'next': 229,
#  'several': 230,
#  'decades': 231,
#  'additional': 232,
#  'therapies': 233,
#  'urgent': 234,
#  'need': 235,
#  'worldwide': 236,
#  'due': 237,
#  'limitations': 238,
#  'costs': 239,
#  'existing': 240,
#  'healthcare': 241,
#  'approaches': 242,
#  'essential': 243,
#  'oil': 244,
#  'aromatherapy': 245,
#  'provide': 246,
#  'costeffective': 247,
#  'safe': 248,
#  'many': 249,
#  'pilot': 250,
#  'observed': 251,
#  'effects': 252,
#  'bergamot': 253,
#  'inhalation': 254,
#  'wellbeing': 255,
#  'measured': 256,
#  'positive': 257,
#  'negative': 258,
#  'affect': 259,
#  'scale': 260,
#  'mentalhealth': 261,
#  'center': 262,
#  'located': 263,
#  'utah': 264,
#  'usa': 265,
#  'fiftyseven': 266,
#  'eligible': 267,
#  'participants': 268,
#  '50': 269,
#  'women': 270,
#  'age': 271,
#  'range': 272,
#  '2370years': 273,
#  'were': 274,
#  'included': 275,
#  'fifteen': 276,
#  'minutes': 277,
#  'exposure': 278,
#  'improved': 279,
#  'feelings': 280,
#  'compared': 281,
#  'control': 282,
#  'group': 283,
#  '17': 284,
#  'unexpectedly': 285,
#  'more': 286,
#  'participated': 287,
#  'experimental': 288,
#  'periods': 289,
#  'rather': 290,
#  'suggesting': 291,
#  'even': 292,
#  'brief': 293,
#  'aroma': 294,
#  'may': 295,
#  'make': 296,
#  'people': 297,
#  'willing': 298,
#  'enroll': 299,
#  'clinical': 300,
#  'trials': 301,
#  'provides': 302,
#  'preliminary': 303,
#  'evidence': 304,
#  'efficacy': 305,
#  'safety': 306,
#  'effective': 307,
#  'adjunct': 308,
#  'improve': 309,
#  'individuals': 310,
#  '2017': 311,
#  'authors': 312,
#  'phytotherapy': 313,
#  'research': 314,
#  'published': 315,
#  'john': 316,
#  'wiley': 317,
#  'sons': 318,
#  'ltd': 319,
#  'background': 320,
#  'communitybased': 321,
#  'participatory': 322,
#  'protection': 323,
#  'was': 324,
#  'understand': 325,
#  'cultural': 326,
#  'experiences': 327,
#  'attitudes': 328,
#  'knowledge': 329,
#  'behaviors': 330,
#  'surrounding': 331,
#  'caries': 332,
#  'etiology': 333,
#  'its': 334,
#  'barriers': 335,
#  'accessing': 336,
#  'oral': 337,
#  'care': 338,
#  'children': 339,
#  'latino': 340,
#  'parents': 341,
#  'residing': 342,
#  'central': 343,
#  'indiana': 344,
#  'methods': 345,
#  'community': 346,
#  'reference': 347,
#  'cbpr': 348,
#  'established': 349,
#  'bilingual': 350,
#  'associates': 351,
#  'conduct': 352,
#  'focus': 353,
#  'groups': 354,
#  'comprised': 355,
#  'caregivers': 356,
#  'transcripts': 357,
#  'analyzed': 358,
#  'thematic': 359,
#  'content': 360,
#  'inductive': 361,
#  'indicated': 362,
#  'significant': 363,
#  'gaps': 364,
#  'parental': 365,
#  'regarding': 366,
#  'underlays': 367,
#  'most': 368,
#  'believed': 369,
#  'related': 370,
#  'childs': 371,
#  'ingestion': 372,
#  'certain': 373,
#  'foods': 374,
#  'containing': 375,
#  'amounts': 376,
#  'carbohydrates': 377,
#  'fewer': 378,
#  'either': 379,
#  'geneticsbiological': 380,
#  'inheritance': 381,
#  'or': 382,
#  'bacteria': 383,
#  'primary': 384,
#  'causative': 385,
#  'fatalism': 386,
#  'negatively': 387,
#  'impacted': 388,
#  'preventive': 389,
#  'practices': 390,
#  'clear': 391,
#  'separation': 392,
#  'existed': 393,
#  'concerning': 394,
#  'perceived': 395,
#  'responsibilities': 396,
#  'mothers': 397,
#  'fathers': 398,
#  'needs': 399,
#  'females': 400,
#  'likely': 401,
#  'report': 402,
#  'they': 403,
#  'primarily': 404,
#  'responsible': 405,
#  'brushing': 406,
#  'childrens': 407,
#  'teeth': 408,
#  'overseeing': 409,
#  'diet': 410,
#  'seeking': 411,
#  'dental': 412,
#  'child': 413,
#  'providing': 414,
#  'pay': 415,
#  'professional': 416,
#  'finances': 417,
#  'communication': 418,
#  'difficulties': 419,
#  'especially': 420,
#  'communicating': 421,
#  'providers': 422,
#  'completing': 423,
#  'insurance': 424,
#  'forms': 425,
#  'conclusion': 426,
#  'main': 427,
#  'implication': 428,
#  'demonstration': 429,
#  'how': 430,
#  'provided': 431,
#  'enhanced': 432,
#  'understanding': 433,
#  'inform': 434,
#  'improvements': 435,
#  'current': 436,
#  'efforts': 437,
#  'continue': 438,
#  'employ': 439,
#  'implement': 440,
#  'programs': 441,
#  'address': 442,
#  'vulnerable': 443,
#  'population': 444,
#  'semantic': 445,
#  'memory': 446,
#  'influenced': 447,
#  'individual': 448,
#  'under': 449,
#  'conditions': 450,
#  'distraction': 451,
#  'question': 452,
#  'addressed': 453,
#  'observing': 454,
#  'recalled': 455,
#  'visual': 456,
#  'target': 457,
#  'wordsdrawn': 458,
#  'categorywhile': 459,
#  'ignoring': 460,
#  'spoken': 461,
#  'distractor': 462,
#  'words': 463,
#  'members': 464,
#  'same': 465,
#  'category': 466,
#  'working': 467,
#  'capacity': 468,
#  'wmc': 469,
#  'disruption': 470,
#  'only': 471,
#  'synchronous': 472,
#  'asynchronous': 473,
#  'presentation': 474,
#  'when': 475,
#  'presented': 476,
#  'synchronously': 477,
#  'subsequent': 478,
#  'experiments': 479,
#  'found': 480,
#  'priming': 481,
#  'distractors': 482,
#  'among': 483,
#  'but': 484,
#  'dependent': 485,
#  'targets': 486,
#  'comparable': 487,
#  'exemplars': 488,
#  'less': 489,
#  'dominant': 490,
#  'recall': 491,
#  'impairedrelative': 492,
#  'controlonly': 493,
#  'low': 494,
#  'highlight': 495,
#  'role': 496,
#  'cognitive': 497,
#  'resources': 498,
#  'targetdistractor': 499,
#  'selection': 500,
#  'individualspecific': 501,
#  'cost': 502,
#  'implications': 503,
#  'such': 504,
#  'genetic': 505,
#  'environmental': 506,
#  'known': 507,
#  'development': 508,
#  'childhood': 509,
#  'eczema': 510,
#  'our': 511,
#  'aim': 512,
#  'assess': 513,
#  'associated': 514,
#  'prevalence': 515,
#  'webbased': 516,
#  'survey': 517,
#  'june': 518,
#  '2012': 519,
#  'conducted': 520,
#  'nationwide': 521,
#  'identify': 522,
#  'characteristics': 523,
#  'allergic': 524,
#  'diseases': 525,
#  'japanese': 526,
#  'including': 527,
#  'assessed': 528,
#  'international': 529,
#  'asthma': 530,
#  'allergies': 531,
#  'core': 532,
#  'associations': 533,
#  'well': 534,
#  'those': 535,
#  'comorbid': 536,
#  '612': 537,
#  'old': 538,
#  'total': 539,
#  '28348': 540,
#  '130': 541,
#  'significantly': 542,
#  'wheeze': 543,
#  'rhinitis': 544,
#  'food': 545,
#  'allergy': 546,
#  'multiple': 547,
#  'logistic': 548,
#  'regression': 549,
#  'birth': 550,
#  'during': 551,
#  'autumn': 552,
#  'aor': 553,
#  '118': 554,
#  '95': 555,
#  'ci': 556,
#  '106131': 557,
#  'winter': 558,
#  '121': 559,
#  '108134': 560,
#  'duration': 561,
#  'exclusive': 562,
#  'breastfeeding': 563,
#  'least': 564,
#  '6': 565,
#  'months': 566,
#  '114': 567,
#  '106123': 568,
#  'ownership': 569,
#  'pet': 570,
#  'infancy': 571,
#  '261': 572,
#  '168407': 573,
#  'also': 574,
#  'lower': 575,
#  'annual': 576,
#  'household': 577,
#  'income': 578,
#  '090': 579,
#  '081099': 580,
#  '2': 581,
#  'siblings': 582,
#  '086': 583,
#  '076097': 584,
#  'conclusions': 585,
#  'season': 586,
#  'web': 587,
#  'copyright': 588,
#  'allergology': 589,
#  'production': 590,
#  'hosting': 591,
#  'elsevier': 592,
#  'bv': 593,
#  'articular': 594,
#  'extraarticular': 595,
#  'manifestations': 596,
#  'hlab27': 597,
#  'undergone': 598,
#  'dramatic': 599,
#  'changes': 600,
#  'past': 601,
#  'mainly': 602,
#  'consequence': 603,
#  'introduction': 604,
#  'biologic': 605,
#  'agents': 606,
#  'particular': 607,
#  'antitumor': 608,
#  'necrosis': 609,
#  'antitnf': 610,
#  'alpha': 611,
#  'uveitis': 612,
#  'frequent': 613,
#  'feature': 614,
#  'hlab27associated': 615,
#  'spondyloarthritides': 616,
#  'topical': 617,
#  'corticosteroids': 618,
#  'cycloplegic': 619,
#  'remain': 620,
#  'cornerstones': 621,
#  'however': 622,
#  'therapy': 623,
#  'management': 624,
#  'refractory': 625,
#  'recurrent': 626,
#  'review': 627,
#  'gives': 628,
#  'update': 629,
#  'ocular': 630,
#  'disorders': 631,
#  'biologics': 632,
#  'nonantitnf': 633,
#  'modifier': 634,
#  'drugs': 635,
#  'emerging': 636,
#  'newer': 637,
#  'targeting': 638,
#  'interleukin1223': 639,
#  'interleukin17': 640,
#  'anterior': 641,
#  'sparse': 642,
#  'resilience': 643,
#  'dynamic': 644,
#  'multifaceted': 645,
#  'which': 646,
#  'draw': 647,
#  'personal': 648,
#  'contextual': 649,
#  'difficult': 650,
#  'situations': 651,
#  'resilient': 652,
#  'use': 653,
#  'specific': 654,
#  'strategies': 655,
#  'learn': 656,
#  'situation': 657,
#  'without': 658,
#  'overcome': 659,
#  'stressors': 660,
#  'inherent': 661,
#  'veterinary': 662,
#  'work': 663,
#  'hours': 664,
#  'ethical': 665,
#  'dilemmas': 666,
#  'challenging': 667,
#  'interactions': 668,
#  'important': 669,
#  'component': 670,
#  'quality': 671,
#  'life': 672,
#  'other': 673,
#  'professionals': 674,
#  'received': 675,
#  'attention': 676,
#  'little': 677,
#  'field': 678,
#  'crosssectional': 679,
#  'students': 680,
#  'six': 681,
#  'schools': 682,
#  'australia': 683,
#  'completed': 684,
#  'online': 685,
#  '193': 686,
#  'responses': 687,
#  '23': 688,
#  'very': 689,
#  'few': 690,
#  'reached': 691,
#  'threshold': 692,
#  'highly': 693,
#  'approximately': 694,
#  'third': 695,
#  'classified': 696,
#  'having': 697,
#  'levels': 698,
#  'final': 699,
#  'linear': 700,
#  'predictors': 701,
#  'nonjudgmental': 702,
#  'nonreactive': 703,
#  'mindfulness': 704,
#  'five': 705,
#  'facet': 706,
#  'selfcompassion': 707,
#  'neff': 708,
#  'had': 709,
#  'scores': 710,
#  'these': 711,
#  'findings': 712,
#  'indicate': 713,
#  'fostering': 714,
#  'qualities': 715,
#  'aligned': 716,
#  'strengthening': 717,
#  'student': 718,
#  'importantly': 719,
#  'if': 720,
#  'help': 721,
#  'identified': 722,
#  'targeted': 723,
#  'educate': 724,
#  'future': 725,
#  'cxcr4using': 726,
#  'hiv1': 727,
#  'previously': 728,
#  'shown': 729,
#  'replicate': 730,
#  'efficiently': 731,
#  'healthy': 732,
#  'donorderived': 733,
#  'cd4': 734,
#  'cd38': 735,
#  'tcell': 736,
#  'subset': 737,
#  'after': 738,
#  'stimulation': 739,
#  'interleukinil4': 740,
#  'here': 741,
#  '3': 742,
#  'cellular': 743,
#  'genes': 744,
#  'expressed': 745,
#  'level': 746,
#  'il4stimulated': 747,
#  'rnf125trac1': 748,
#  'involved': 749,
#  'downregulation': 750,
#  'replication': 751,
#  'cell': 752,
#  'lines': 753,
#  'peripheral': 754,
#  'blood': 755,
#  'mononuclear': 756,
#  'rnfi25trac1': 757,
#  'bears': 758,
#  'ring': 759,
#  'finger': 760,
#  'domain': 761,
#  'e3': 762,
#  'ubiquitin': 763,
#  'protein': 764,
#  'ligase': 765,
#  'mutations': 766,
#  'rnfl25trac1': 767,
#  'led': 768,
#  'loss': 769,
#  'downmodulatory': 770,
#  'activity': 771,
#  'necessary': 772,
#  'northern': 773,
#  'blotting': 774,
#  'reporter': 775,
#  'gene': 776,
#  'function': 777,
#  'occurs': 778,
#  'viral': 779,
#  'transcription': 780,
#  'suggest': 781,
#  'could': 782,
#  'recruit': 783,
#  'host': 784,
#  'controlling': 785,
#  'ubiquitinproteasome': 786,
#  'pathway': 787,
#  '2007': 788,
#  'inc': 789,
#  'all': 790,
#  'rights': 791,
#  'reserved': 792,
#  'cortana': 793,
#  'new': 794,
#  'features': 795,
#  'introduced': 796,
#  'microsoft': 797,
#  'windows': 798,
#  '10': 799,
#  'desktop': 800,
#  'operating': 801,
#  'systems': 802,
#  'voice': 803,
#  'activated': 804,
#  'digital': 805,
#  'assistant': 806,
#  'searching': 807,
#  'stuff': 808,
#  'device': 809,
#  'setting': 810,
#  'up': 811,
#  'reminders': 812,
#  'tracking': 813,
#  'users': 814,
#  'upcoming': 815,
#  'flights': 816,
#  'getting': 817,
#  'news': 818,
#  'tailored': 819,
#  'interests': 820,
#  'sending': 821,
#  'emails': 822,
#  'platform': 823,
#  'relatively': 824,
#  'forensic': 825,
#  'examination': 826,
#  'largely': 827,
#  'unexplored': 828,
#  'literature': 829,
#  'paper': 830,
#  'seeks': 831,
#  'determine': 832,
#  'remnants': 833,
#  'usage': 834,
#  'pc': 835,
#  'contributes': 836,
#  'indepth': 837,
#  'location': 838,
#  'evidentiary': 839,
#  'artifacts': 840,
#  'hard': 841,
#  'disk': 842,
#  'type': 843,
#  'information': 844,
#  'recorded': 845,
#  'result': 846,
#  'user': 847,
#  'activities': 848,
#  'decoding': 849,
#  'exporting': 850,
#  'databases': 851,
#  'created': 852,
#  'application': 853,
#  'custom': 854,
#  'python': 855,
#  'scripts': 856,
#  'developed': 857,
#  'additionally': 858,
#  'gui': 859,
#  'tool': 860,
#  'called': 861,
#  'cortanadigger': 862,
#  'extracting': 863,
#  'listing': 864,
#  'search': 865,
#  'strings': 866,
#  'timestamp': 867,
#  'made': 868,
#  'box': 869,
#  'track': 870,
#  'place': 871,
#  'person': 872,
#  'detect': 873,
#  'anti': 874,
#  'attempts': 875,
#  'like': 876,
#  'modification': 877,
#  'destruction': 878,
#  'carried': 879,
#  'out': 880,
#  'finally': 881,
#  'usefulness': 882,
#  'demonstrated': 883,
#  'terms': 884,
#  'timeline': 885,
#  'constructed': 886,
#  'period': 887,
#  'objective': 888,
#  'examine': 889,
#  'relationships': 890,
#  'spirituality': 891,
#  'physical': 892,
#  'sedentary': 893,
#  'behavior': 894,
#  'sample': 895,
#  'adults': 896,
#  'massachusetts': 897,
#  'design': 898,
#  'lawrence': 899,
#  'patients': 900,
#  'family': 901,
#  'glfhc': 902,
#  '602': 903,
#  'hispanic': 904,
#  'aged': 905,
#  '21': 906,
#  '85': 907,
#  'years': 908,
#  'relationship': 909,
#  'beta': 910,
#  '12': 911,
#  'p': 912,
#  '004': 913,
#  'although': 914,
#  'statistically': 915,
#  'increased': 916,
#  'odds': 917,
#  'engaging': 918,
#  'men': 919,
#  '005': 920,
#  'who': 921,
#  'spiritual': 922,
#  'association': 923,
#  'stronger': 924,
#  'insight': 925,
#  'developing': 926,
#  'interventions': 927,
#  'promote': 928,
#  'highrisk': 929,
#  'greatly': 930,
#  'understudied': 931,
#  'endeavors': 932,
#  'should': 933,
#  'consider': 934,
#  'investigating': 935,
#  'impact': 936,
#  'spiritualitybased': 937,
#  'messages': 938,
#  'reduce': 939,
#  'latinos': 940,
#  'objectiveimpairment': 941,
#  'frequently': 942,
#  'alzheimers': 943,
#  'disease': 944,
#  'ad': 945,
#  'cause': 946,
#  'severe': 947,
#  'constraints': 948,
#  'daily': 949,
#  'nonverbal': 950,
#  'ravens': 951,
#  'colored': 952,
#  'progressive': 953,
#  'matrices': 954,
#  'rcpm': 955,
#  'test': 956,
#  'consists': 957,
#  'sets': 958,
#  'ab': 959,
#  'b': 960,
#  'performed': 961,
#  'short': 962,
#  'evaluate': 963,
#  'reasoning': 964,
#  'ability': 965,
#  'purpose': 966,
#  'neural': 967,
#  'basis': 968,
#  'singlephoton': 969,
#  'emission': 970,
#  'computed': 971,
#  'tomography': 972,
#  'spect': 973,
#  'methodsfifty': 974,
#  'fulfilled': 975,
#  'national': 976,
#  'institute': 977,
#  'agingalzheimers': 978,
#  'criteria': 979,
#  'probable': 980,
#  'dementia': 981,
#  'examined': 982,
#  'spects': 983,
#  'nisopropylpi123iodoamphetamine': 984,
#  'perform': 985,
#  'multivariate': 986,
#  'analyses': 987,
#  'regional': 988,
#  'cerebral': 989,
#  'rcbf': 990,
#  'resultsthere': 991,
#  'score': 992,
#  'inferior': 993,
#  'parietal': 994,
#  'lobes': 995,
#  'bilaterally': 996,
#  'right': 997,
#  'temporal': 998,
#  'gyrus': 999,
#  ...}

# %%
tokenizer.index2token
# Out:
# ['the',
#  'article',
#  'acquaints',
#  'with',
#  'means',
#  'of',
#  'dramatherapeutic',
#  'intervention',
#  'in',
#  'two',
#  'addictions',
#  'departments',
#  '',
#  'centre',
#  'for',
#  'secondary',
#  'prevention',
#  'and',
#  'addiction',
#  'treatment',
#  'at',
#  'military',
#  'hospital',
#  'olomouc',
#  'toxicorehabilitation',
#  'department',
#  'psychiatric',
#  'kromeriz',
#  'first',
#  'runs',
#  'a',
#  'detoxification',
#  'shortterm',
#  'one',
#  'month',
#  'programme',
#  'while',
#  'mandala',
#  'mediumterm',
#  'as',
#  'long',
#  'half',
#  'year',
#  'is',
#  'being',
#  'implemented',
#  'second',
#  'part',
#  'text',
#  'presents',
#  'results',
#  'an',
#  'enquiry',
#  'focused',
#  'on',
#  'tracing',
#  'differences',
#  'connections',
#  'between',
#  'clients',
#  'perception',
#  'benefits',
#  'overall',
#  'concept',
#  'above',
#  'said',
#  'implementation',
#  'questionnaire',
#  'method',
#  'did',
#  'not',
#  'reveal',
#  'evaluations',
#  'both',
#  'key',
#  'factors',
#  'dambreak',
#  'modeling',
#  'are',
#  'accuracy',
#  'speed',
#  'therefore',
#  'highperformance',
#  'calculations',
#  'great',
#  'importance',
#  'to',
#  'simulation',
#  'events',
#  'this',
#  'study',
#  'we',
#  'develop',
#  'twodimensional',
#  'hydrodynamic',
#  'model',
#  'based',
#  'finite',
#  'volume',
#  'simulate',
#  'flow',
#  'routing',
#  'process',
#  'roes',
#  'approximate',
#  'riemann',
#  'solution',
#  'adopted',
#  'solve',
#  'interface',
#  'flux',
#  'grid',
#  'cells',
#  'accurately',
#  'discontinuous',
#  'graphics',
#  'processing',
#  'unit',
#  'gpubased',
#  'parallel',
#  'openacc',
#  'used',
#  'realize',
#  'computing',
#  'because',
#  'explicit',
#  'discrete',
#  'technique',
#  'governing',
#  'equations',
#  'there',
#  'no',
#  'correlation',
#  'single',
#  'time',
#  'step',
#  'can',
#  'be',
#  'easily',
#  'realized',
#  'by',
#  'adding',
#  'directives',
#  'loop',
#  'structure',
#  'analyze',
#  'performance',
#  'considered',
#  'pangtoupao',
#  'flood',
#  'storage',
#  'area',
#  'china',
#  'using',
#  'nvidia',
#  'tesla',
#  'k20c',
#  'card',
#  'four',
#  'different',
#  'division',
#  'schemes',
#  'carefully',
#  'studying',
#  'optimization',
#  'data',
#  'transportation',
#  'algorithm',
#  'speedup',
#  'factor',
#  '2070',
#  'achieved',
#  'acceleration',
#  'better',
#  'than',
#  'that',
#  'openmp',
#  '16kernel',
#  'computer',
#  'further',
#  'analysis',
#  'reveals',
#  'models',
#  'involving',
#  'larger',
#  'number',
#  'exhibit',
#  'greater',
#  'efficiency',
#  'higher',
#  'rate',
#  'addition',
#  'mode',
#  'has',
#  'good',
#  'portability',
#  'making',
#  'it',
#  'easy',
#  'computation',
#  'from',
#  'original',
#  'serial',
#  'advantages',
#  'high',
#  'available',
#  'required',
#  'hardware',
#  'c',
#  '2016',
#  'american',
#  'society',
#  'civil',
#  'engineers',
#  'mental',
#  'health',
#  'issues',
#  'have',
#  'been',
#  'increasingly',
#  'recognized',
#  'public',
#  'problems',
#  'globally',
#  'their',
#  'burden',
#  'projected',
#  'increase',
#  'over',
#  'next',
#  'several',
#  'decades',
#  'additional',
#  'therapies',
#  'urgent',
#  'need',
#  'worldwide',
#  'due',
#  'limitations',
#  'costs',
#  'existing',
#  'healthcare',
#  'approaches',
#  'essential',
#  'oil',
#  'aromatherapy',
#  'provide',
#  'costeffective',
#  'safe',
#  'many',
#  'pilot',
#  'observed',
#  'effects',
#  'bergamot',
#  'inhalation',
#  'wellbeing',
#  'measured',
#  'positive',
#  'negative',
#  'affect',
#  'scale',
#  'mentalhealth',
#  'center',
#  'located',
#  'utah',
#  'usa',
#  'fiftyseven',
#  'eligible',
#  'participants',
#  '50',
#  'women',
#  'age',
#  'range',
#  '2370years',
#  'were',
#  'included',
#  'fifteen',
#  'minutes',
#  'exposure',
#  'improved',
#  'feelings',
#  'compared',
#  'control',
#  'group',
#  '17',
#  'unexpectedly',
#  'more',
#  'participated',
#  'experimental',
#  'periods',
#  'rather',
#  'suggesting',
#  'even',
#  'brief',
#  'aroma',
#  'may',
#  'make',
#  'people',
#  'willing',
#  'enroll',
#  'clinical',
#  'trials',
#  'provides',
#  'preliminary',
#  'evidence',
#  'efficacy',
#  'safety',
#  'effective',
#  'adjunct',
#  'improve',
#  'individuals',
#  '2017',
#  'authors',
#  'phytotherapy',
#  'research',
#  'published',
#  'john',
#  'wiley',
#  'sons',
#  'ltd',
#  'background',
#  'communitybased',
#  'participatory',
#  'protection',
#  'was',
#  'understand',
#  'cultural',
#  'experiences',
#  'attitudes',
#  'knowledge',
#  'behaviors',
#  'surrounding',
#  'caries',
#  'etiology',
#  'its',
#  'barriers',
#  'accessing',
#  'oral',
#  'care',
#  'children',
#  'latino',
#  'parents',
#  'residing',
#  'central',
#  'indiana',
#  'methods',
#  'community',
#  'reference',
#  'cbpr',
#  'established',
#  'bilingual',
#  'associates',
#  'conduct',
#  'focus',
#  'groups',
#  'comprised',
#  'caregivers',
#  'transcripts',
#  'analyzed',
#  'thematic',
#  'content',
#  'inductive',
#  'indicated',
#  'significant',
#  'gaps',
#  'parental',
#  'regarding',
#  'underlays',
#  'most',
#  'believed',
#  'related',
#  'childs',
#  'ingestion',
#  'certain',
#  'foods',
#  'containing',
#  'amounts',
#  'carbohydrates',
#  'fewer',
#  'either',
#  'geneticsbiological',
#  'inheritance',
#  'or',
#  'bacteria',
#  'primary',
#  'causative',
#  'fatalism',
#  'negatively',
#  'impacted',
#  'preventive',
#  'practices',
#  'clear',
#  'separation',
#  'existed',
#  'concerning',
#  'perceived',
#  'responsibilities',
#  'mothers',
#  'fathers',
#  'needs',
#  'females',
#  'likely',
#  'report',
#  'they',
#  'primarily',
#  'responsible',
#  'brushing',
#  'childrens',
#  'teeth',
#  'overseeing',
#  'diet',
#  'seeking',
#  'dental',
#  'child',
#  'providing',
#  'pay',
#  'professional',
#  'finances',
#  'communication',
#  'difficulties',
#  'especially',
#  'communicating',
#  'providers',
#  'completing',
#  'insurance',
#  'forms',
#  'conclusion',
#  'main',
#  'implication',
#  'demonstration',
#  'how',
#  'provided',
#  'enhanced',
#  'understanding',
#  'inform',
#  'improvements',
#  'current',
#  'efforts',
#  'continue',
#  'employ',
#  'implement',
#  'programs',
#  'address',
#  'vulnerable',
#  'population',
#  'semantic',
#  'memory',
#  'influenced',
#  'individual',
#  'under',
#  'conditions',
#  'distraction',
#  'question',
#  'addressed',
#  'observing',
#  'recalled',
#  'visual',
#  'target',
#  'wordsdrawn',
#  'categorywhile',
#  'ignoring',
#  'spoken',
#  'distractor',
#  'words',
#  'members',
#  'same',
#  'category',
#  'working',
#  'capacity',
#  'wmc',
#  'disruption',
#  'only',
#  'synchronous',
#  'asynchronous',
#  'presentation',
#  'when',
#  'presented',
#  'synchronously',
#  'subsequent',
#  'experiments',
#  'found',
#  'priming',
#  'distractors',
#  'among',
#  'but',
#  'dependent',
#  'targets',
#  'comparable',
#  'exemplars',
#  'less',
#  'dominant',
#  'recall',
#  'impairedrelative',
#  'controlonly',
#  'low',
#  'highlight',
#  'role',
#  'cognitive',
#  'resources',
#  'targetdistractor',
#  'selection',
#  'individualspecific',
#  'cost',
#  'implications',
#  'such',
#  'genetic',
#  'environmental',
#  'known',
#  'development',
#  'childhood',
#  'eczema',
#  'our',
#  'aim',
#  'assess',
#  'associated',
#  'prevalence',
#  'webbased',
#  'survey',
#  'june',
#  '2012',
#  'conducted',
#  'nationwide',
#  'identify',
#  'characteristics',
#  'allergic',
#  'diseases',
#  'japanese',
#  'including',
#  'assessed',
#  'international',
#  'asthma',
#  'allergies',
#  'core',
#  'associations',
#  'well',
#  'those',
#  'comorbid',
#  '612',
#  'old',
#  'total',
#  '28348',
#  '130',
#  'significantly',
#  'wheeze',
#  'rhinitis',
#  'food',
#  'allergy',
#  'multiple',
#  'logistic',
#  'regression',
#  'birth',
#  'during',
#  'autumn',
#  'aor',
#  '118',
#  '95',
#  'ci',
#  '106131',
#  'winter',
#  '121',
#  '108134',
#  'duration',
#  'exclusive',
#  'breastfeeding',
#  'least',
#  '6',
#  'months',
#  '114',
#  '106123',
#  'ownership',
#  'pet',
#  'infancy',
#  '261',
#  '168407',
#  'also',
#  'lower',
#  'annual',
#  'household',
#  'income',
#  '090',
#  '081099',
#  '2',
#  'siblings',
#  '086',
#  '076097',
#  'conclusions',
#  'season',
#  'web',
#  'copyright',
#  'allergology',
#  'production',
#  'hosting',
#  'elsevier',
#  'bv',
#  'articular',
#  'extraarticular',
#  'manifestations',
#  'hlab27',
#  'undergone',
#  'dramatic',
#  'changes',
#  'past',
#  'mainly',
#  'consequence',
#  'introduction',
#  'biologic',
#  'agents',
#  'particular',
#  'antitumor',
#  'necrosis',
#  'antitnf',
#  'alpha',
#  'uveitis',
#  'frequent',
#  'feature',
#  'hlab27associated',
#  'spondyloarthritides',
#  'topical',
#  'corticosteroids',
#  'cycloplegic',
#  'remain',
#  'cornerstones',
#  'however',
#  'therapy',
#  'management',
#  'refractory',
#  'recurrent',
#  'review',
#  'gives',
#  'update',
#  'ocular',
#  'disorders',
#  'biologics',
#  'nonantitnf',
#  'modifier',
#  'drugs',
#  'emerging',
#  'newer',
#  'targeting',
#  'interleukin1223',
#  'interleukin17',
#  'anterior',
#  'sparse',
#  'resilience',
#  'dynamic',
#  'multifaceted',
#  'which',
#  'draw',
#  'personal',
#  'contextual',
#  'difficult',
#  'situations',
#  'resilient',
#  'use',
#  'specific',
#  'strategies',
#  'learn',
#  'situation',
#  'without',
#  'overcome',
#  'stressors',
#  'inherent',
#  'veterinary',
#  'work',
#  'hours',
#  'ethical',
#  'dilemmas',
#  'challenging',
#  'interactions',
#  'important',
#  'component',
#  'quality',
#  'life',
#  'other',
#  'professionals',
#  'received',
#  'attention',
#  'little',
#  'field',
#  'crosssectional',
#  'students',
#  'six',
#  'schools',
#  'australia',
#  'completed',
#  'online',
#  '193',
#  'responses',
#  '23',
#  'very',
#  'few',
#  'reached',
#  'threshold',
#  'highly',
#  'approximately',
#  'third',
#  'classified',
#  'having',
#  'levels',
#  'final',
#  'linear',
#  'predictors',
#  'nonjudgmental',
#  'nonreactive',
#  'mindfulness',
#  'five',
#  'facet',
#  'selfcompassion',
#  'neff',
#  'had',
#  'scores',
#  'these',
#  'findings',
#  'indicate',
#  'fostering',
#  'qualities',
#  'aligned',
#  'strengthening',
#  'student',
#  'importantly',
#  'if',
#  'help',
#  'identified',
#  'targeted',
#  'educate',
#  'future',
#  'cxcr4using',
#  'hiv1',
#  'previously',
#  'shown',
#  'replicate',
#  'efficiently',
#  'healthy',
#  'donorderived',
#  'cd4',
#  'cd38',
#  'tcell',
#  'subset',
#  'after',
#  'stimulation',
#  'interleukinil4',
#  'here',
#  '3',
#  'cellular',
#  'genes',
#  'expressed',
#  'level',
#  'il4stimulated',
#  'rnf125trac1',
#  'involved',
#  'downregulation',
#  'replication',
#  'cell',
#  'lines',
#  'peripheral',
#  'blood',
#  'mononuclear',
#  'rnfi25trac1',
#  'bears',
#  'ring',
#  'finger',
#  'domain',
#  'e3',
#  'ubiquitin',
#  'protein',
#  'ligase',
#  'mutations',
#  'rnfl25trac1',
#  'led',
#  'loss',
#  'downmodulatory',
#  'activity',
#  'necessary',
#  'northern',
#  'blotting',
#  'reporter',
#  'gene',
#  'function',
#  'occurs',
#  'viral',
#  'transcription',
#  'suggest',
#  'could',
#  'recruit',
#  'host',
#  'controlling',
#  'ubiquitinproteasome',
#  'pathway',
#  '2007',
#  'inc',
#  'all',
#  'rights',
#  'reserved',
#  'cortana',
#  'new',
#  'features',
#  'introduced',
#  'microsoft',
#  'windows',
#  '10',
#  'desktop',
#  'operating',
#  'systems',
#  'voice',
#  'activated',
#  'digital',
#  'assistant',
#  'searching',
#  'stuff',
#  'device',
#  'setting',
#  'up',
#  'reminders',
#  'tracking',
#  'users',
#  'upcoming',
#  'flights',
#  'getting',
#  'news',
#  'tailored',
#  'interests',
#  'sending',
#  'emails',
#  'platform',
#  'relatively',
#  'forensic',
#  'examination',
#  'largely',
#  'unexplored',
#  'literature',
#  'paper',
#  'seeks',
#  'determine',
#  'remnants',
#  'usage',
#  'pc',
#  'contributes',
#  'indepth',
#  'location',
#  'evidentiary',
#  'artifacts',
#  'hard',
#  'disk',
#  'type',
#  'information',
#  'recorded',
#  'result',
#  'user',
#  'activities',
#  'decoding',
#  'exporting',
#  'databases',
#  'created',
#  'application',
#  'custom',
#  'python',
#  'scripts',
#  'developed',
#  'additionally',
#  'gui',
#  'tool',
#  'called',
#  'cortanadigger',
#  'extracting',
#  'listing',
#  'search',
#  'strings',
#  'timestamp',
#  'made',
#  'box',
#  'track',
#  'place',
#  'person',
#  'detect',
#  'anti',
#  'attempts',
#  'like',
#  'modification',
#  'destruction',
#  'carried',
#  'out',
#  'finally',
#  'usefulness',
#  'demonstrated',
#  'terms',
#  'timeline',
#  'constructed',
#  'period',
#  'objective',
#  'examine',
#  'relationships',
#  'spirituality',
#  'physical',
#  'sedentary',
#  'behavior',
#  'sample',
#  'adults',
#  'massachusetts',
#  'design',
#  'lawrence',
#  'patients',
#  'family',
#  'glfhc',
#  '602',
#  'hispanic',
#  'aged',
#  '21',
#  '85',
#  'years',
#  'relationship',
#  'beta',
#  '12',
#  'p',
#  '004',
#  'although',
#  'statistically',
#  'increased',
#  'odds',
#  'engaging',
#  'men',
#  '005',
#  'who',
#  'spiritual',
#  'association',
#  'stronger',
#  'insight',
#  'developing',
#  'interventions',
#  'promote',
#  'highrisk',
#  'greatly',
#  'understudied',
#  'endeavors',
#  'should',
#  'consider',
#  'investigating',
#  'impact',
#  'spiritualitybased',
#  'messages',
#  'reduce',
#  'latinos',
#  'objectiveimpairment',
#  'frequently',
#  'alzheimers',
#  'disease',
#  'ad',
#  'cause',
#  'severe',
#  'constraints',
#  'daily',
#  'nonverbal',
#  'ravens',
#  'colored',
#  'progressive',
#  'matrices',
#  'rcpm',
#  'test',
#  'consists',
#  'sets',
#  'ab',
#  'b',
#  'performed',
#  'short',
#  'evaluate',
#  'reasoning',
#  'ability',
#  'purpose',
#  'neural',
#  'basis',
#  'singlephoton',
#  'emission',
#  'computed',
#  'tomography',
#  'spect',
#  'methodsfifty',
#  'fulfilled',
#  'national',
#  'institute',
#  'agingalzheimers',
#  'criteria',
#  'probable',
#  'dementia',
#  'examined',
#  'spects',
#  'nisopropylpi123iodoamphetamine',
#  'perform',
#  'multivariate',
#  'analyses',
#  'regional',
#  'cerebral',
#  'rcbf',
#  'resultsthere',
#  'score',
#  'inferior',
#  'parietal',
#  'lobes',
#  'bilaterally',
#  'right',
#  'temporal',
#  'gyrus',
#  ...]

# %%
tokenizer.token2count
# Out:
# Counter({'the': 346316,
#          'article': 1921,
#          'acquaints': 1,
#          'with': 69287,
#          'means': 1028,
#          'of': 252243,
#          'dramatherapeutic': 3,
#          'intervention': 2043,
#          'in': 154465,
#          'two': 8032,
#          'addictions': 38,
#          'departments': 96,
#          '': 23548,
#          'centre': 168,
#          'for': 65614,
#          'secondary': 1059,
#          'prevention': 1053,
#          'and': 229808,
#          'addiction': 391,
#          'treatment': 8493,
#          'at': 17828,
#          'military': 159,
#          'hospital': 1005,
#          'olomouc': 4,
#          'toxicorehabilitation': 1,
#          'department': 389,
#          'psychiatric': 881,
#          'kromeriz': 1,
#          'first': 4622,
#          'runs': 90,
#          'a': 109553,
#          'detoxification': 44,
#          'shortterm': 275,
#          'one': 6540,
#          'month': 347,
#          'programme': 252,
#          'while': 4388,
#          'mandala': 1,
#          'mediumterm': 18,
#          'as': 35777,
#          'long': 950,
#          'half': 435,
#          'year': 1197,
#          'is': 60182,
#          'being': 2136,
#          'implemented': 1240,
#          'second': 1502,
#          'part': 1791,
#          'text': 313,
#          'presents': 1915,
#          'results': 18048,
#          'an': 25725,
#          'enquiry': 12,
#          'focused': 873,
#          'on': 37957,
#          'tracing': 67,
#          'differences': 2906,
#          'connections': 185,
#          'between': 13605,
#          'clients': 212,
#          'perception': 687,
#          'benefits': 1021,
#          'overall': 2231,
#          'concept': 970,
#          'above': 648,
#          'said': 70,
#          'implementation': 1641,
#          'questionnaire': 1214,
#          'method': 8047,
#          'did': 2097,
#          'not': 11967,
#          'reveal': 533,
#          'evaluations': 288,
#          'both': 8335,
#          'key': 2371,
#          'factors': 5106,
#          'dambreak': 10,
#          'modeling': 1377,
#          'are': 32756,
#          'accuracy': 1780,
#          'speed': 1163,
#          'therefore': 2306,
#          'highperformance': 162,
#          'calculations': 256,
#          'great': 768,
#          'importance': 1427,
#          'to': 130980,
#          'simulation': 2355,
#          'events': 1582,
#          'this': 38940,
#          'study': 19329,
#          'we': 25956,
#          'develop': 1416,
#          'twodimensional': 206,
#          'hydrodynamic': 100,
#          'model': 10497,
#          'based': 8364,
#          'finite': 625,
#          'volume': 1213,
#          'simulate': 286,
#          'flow': 2552,
#          'routing': 171,
#          'process': 4480,
#          'roes': 1,
#          'approximate': 268,
#          'riemann': 16,
#          'solution': 1748,
#          'adopted': 493,
#          'solve': 576,
#          'interface': 726,
#          'flux': 376,
#          'grid': 564,
#          'cells': 6358,
#          'accurately': 443,
#          'discontinuous': 41,
#          'graphics': 339,
#          'processing': 2257,
#          'unit': 766,
#          'gpubased': 31,
#          'parallel': 1341,
#          'openacc': 6,
#          'used': 11739,
#          'realize': 198,
#          'computing': 1300,
#          'because': 2150,
#          'explicit': 312,
#          'discrete': 363,
#          'technique': 1923,
#          'governing': 140,
#          'equations': 977,
#          'there': 5304,
#          'no': 5038,
#          'correlation': 1459,
#          'single': 2016,
#          'time': 6759,
#          'step': 828,
#          'can': 13326,
#          'be': 22694,
#          'easily': 504,
#          'realized': 229,
#          'by': 36420,
#          'adding': 228,
#          'directives': 9,
#          'loop': 406,
#          'structure': 2887,
#          'analyze': 924,
#          'performance': 5901,
#          'considered': 2329,
#          'pangtoupao': 1,
#          'flood': 152,
#          'storage': 1114,
#          'area': 2287,
#          'china': 658,
#          'using': 14230,
#          'nvidia': 24,
#          'tesla': 16,
#          'k20c': 2,
#          'card': 63,
#          'four': 2132,
#          'different': 7990,
#          'division': 143,
#          'schemes': 464,
#          'carefully': 156,
#          'studying': 318,
#          'optimization': 1491,
#          'data': 13452,
#          'transportation': 167,
#          'algorithm': 3676,
#          'speedup': 105,
#          'factor': 2726,
#          '2070': 4,
#          'achieved': 1157,
#          'acceleration': 236,
#          'better': 2524,
#          'than': 8691,
#          'that': 45212,
#          'openmp': 19,
#          '16kernel': 1,
#          'computer': 1679,
#          'further': 3606,
#          'analysis': 10081,
#          'reveals': 278,
#          'models': 4259,
#          'involving': 640,
#          'larger': 795,
#          'number': 4184,
#          'exhibit': 403,
#          'greater': 1949,
#          'efficiency': 2393,
#          'higher': 5594,
#          'rate': 3392,
#          'addition': 2733,
#          'mode': 848,
#          'has': 12954,
#          'good': 1567,
#          'portability': 33,
#          'making': 800,
#          'it': 11865,
#          'easy': 401,
#          'computation': 696,
#          'from': 23850,
#          'original': 612,
#          'serial': 134,
#          'advantages': 675,
#          'high': 7102,
#          'available': 2187,
#          'required': 1585,
#          'hardware': 536,
#          'c': 10471,
#          '2016': 4013,
#          'american': 840,
#          'society': 963,
#          'civil': 293,
#          'engineers': 378,
#          'mental': 1665,
#          'health': 6941,
#          'issues': 1247,
#          'have': 14176,
#          'been': 10979,
#          'increasingly': 625,
#          'recognized': 371,
#          'public': 1151,
#          'problems': 2518,
#          'globally': 128,
#          'their': 11508,
#          'burden': 577,
#          'projected': 90,
#          'increase': 3317,
#          'over': 4012,
#          'next': 494,
#          'several': 3246,
#          'decades': 524,
#          'additional': 1261,
#          'therapies': 648,
#          'urgent': 95,
#          'need': 2198,
#          'worldwide': 468,
#          'due': 3638,
#          'limitations': 777,
#          'costs': 981,
#          'existing': 1695,
#          'healthcare': 702,
#          'approaches': 1721,
#          'essential': 1220,
#          'oil': 486,
#          'aromatherapy': 9,
#          'provide': 3678,
#          'costeffective': 182,
#          'safe': 500,
#          'many': 3270,
#          'pilot': 273,
#          'observed': 3266,
#          'effects': 6026,
#          'bergamot': 6,
#          'inhalation': 43,
#          'wellbeing': 641,
#          'measured': 2386,
#          'positive': 2928,
#          'negative': 2304,
#          'affect': 1439,
#          'scale': 2000,
#          'mentalhealth': 3,
#          'center': 667,
#          'located': 484,
#          'utah': 8,
#          'usa': 174,
#          'fiftyseven': 13,
#          'eligible': 241,
#          'participants': 4063,
#          '50': 1291,
#          'women': 4596,
#          'age': 4622,
#          'range': 2694,
#          '2370years': 1,
#          'were': 38493,
#          'included': 2793,
#          'fifteen': 78,
#          'minutes': 146,
#          'exposure': 2043,
#          'improved': 2047,
#          'feelings': 143,
#          'compared': 7238,
#          'control': 8892,
#          'group': 6668,
#          '17': 674,
#          'unexpectedly': 47,
#          'more': 10095,
#          'participated': 396,
#          'experimental': 2978,
#          'periods': 415,
#          'rather': 766,
#          'suggesting': 883,
#          'even': 1629,
#          'brief': 342,
#          'aroma': 4,
#          'may': 8454,
#          'make': 960,
#          'people': 1929,
#          'willing': 54,
#          'enroll': 18,
#          'clinical': 5720,
#          'trials': 1042,
#          'provides': 2034,
#          'preliminary': 412,
#          'evidence': 2988,
#          'efficacy': 1367,
#          'safety': 1334,
#          'effective': 2890,
#          'adjunct': 49,
#          'improve': 2510,
#          'individuals': 2561,
#          '2017': 2389,
#          'authors': 1301,
#          'phytotherapy': 5,
#          'research': 6843,
#          'published': 2237,
#          'john': 398,
#          'wiley': 717,
#          'sons': 413,
#          'ltd': 3645,
#          'background': 3390,
#          'communitybased': 128,
#          'participatory': 61,
#          'protection': 618,
#          'was': 37832,
#          'understand': 972,
#          'cultural': 472,
#          'experiences': 721,
#          'attitudes': 825,
#          'knowledge': 2693,
#          'behaviors': 1390,
#          'surrounding': 241,
#          'caries': 48,
#          'etiology': 275,
#          'its': 7268,
#          'barriers': 514,
#          'accessing': 75,
#          'oral': 926,
#          'care': 3652,
#          'children': 4191,
#          'latino': 81,
#          'parents': 1251,
#          'residing': 45,
#          'central': 1053,
#          'indiana': 6,
#          'methods': 8345,
#          'community': 1248,
#          'reference': 1025,
#          'cbpr': 19,
#          'established': 1248,
#          'bilingual': 30,
#          'associates': 49,
#          'conduct': 357,
#          'focus': 1390,
#          'groups': 3836,
#          'comprised': 222,
#          'caregivers': 359,
#          'transcripts': 258,
#          'analyzed': 2226,
#          'thematic': 172,
#          'content': 1477,
#          'inductive': 72,
#          'indicated': 1487,
#          'significant': 6208,
#          'gaps': 210,
#          'parental': 704,
#          'regarding': 1528,
#          'underlays': 1,
#          'most': 6343,
#          'believed': 205,
#          'related': 3573,
#          'childs': 192,
#          'ingestion': 83,
#          'certain': 826,
#          'foods': 226,
#          'containing': 728,
#          'amounts': 287,
#          'carbohydrates': 45,
#          'fewer': 373,
#          'either': 1517,
#          'geneticsbiological': 1,
#          'inheritance': 58,
#          'or': 18599,
#          'bacteria': 508,
#          'primary': 2462,
#          'causative': 92,
#          'fatalism': 9,
#          'negatively': 522,
#          'impacted': 98,
#          'preventive': 235,
#          'practices': 994,
#          'clear': 520,
#          'separation': 326,
#          'existed': 64,
#          'concerning': 413,
#          'perceived': 923,
#          'responsibilities': 75,
#          'mothers': 878,
#          'fathers': 232,
#          'needs': 1169,
#          'females': 800,
#          'likely': 1695,
#          'report': 1477,
#          'they': 4132,
#          'primarily': 435,
#          'responsible': 511,
#          'brushing': 4,
#          'childrens': 956,
#          'teeth': 94,
#          'overseeing': 3,
#          'diet': 695,
#          'seeking': 250,
#          'dental': 267,
#          'child': 1707,
#          'providing': 951,
#          'pay': 103,
#          'professional': 404,
#          'finances': 7,
#          'communication': 1769,
#          'difficulties': 524,
#          'especially': 1600,
#          'communicating': 54,
#          'providers': 504,
#          'completing': 80,
#          'insurance': 216,
#          'forms': 792,
#          'conclusion': 2599,
#          'main': 2425,
#          'implication': 78,
#          'demonstration': 116,
#          'how': 3447,
#          'provided': 1516,
#          'enhanced': 929,
#          'understanding': 2300,
#          'inform': 287,
#          'improvements': 561,
#          'current': 4288,
#          'efforts': 558,
#          'continue': 219,
#          'employ': 148,
#          'implement': 451,
#          'programs': 973,
#          'address': 980,
#          'vulnerable': 278,
#          'population': 2595,
#          'semantic': 318,
#          'memory': 2050,
#          'influenced': 493,
#          'individual': 1577,
#          'under': 3450,
#          'conditions': 3662,
#          'distraction': 36,
#          'question': 445,
#          'addressed': 459,
#          'observing': 62,
#          'recalled': 43,
#          'visual': 1110,
#          'target': 1733,
#          'wordsdrawn': 1,
#          'categorywhile': 1,
#          'ignoring': 25,
#          'spoken': 34,
#          'distractor': 10,
#          'words': 342,
#          'members': 728,
#          'same': 2030,
#          'category': 262,
#          'working': 887,
#          'capacity': 1234,
#          'wmc': 7,
#          'disruption': 199,
#          'only': 4795,
#          'synchronous': 219,
#          'asynchronous': 63,
#          'presentation': 460,
#          'when': 5356,
#          'presented': 3135,
#          'synchronously': 11,
#          'subsequent': 659,
#          'experiments': 1768,
#          'found': 5359,
#          'priming': 91,
#          'distractors': 26,
#          'among': 5418,
#          'but': 7721,
#          'dependent': 598,
#          'targets': 826,
#          'comparable': 439,
#          'exemplars': 9,
#          'less': 2560,
#          'dominant': 361,
#          'recall': 308,
#          'impairedrelative': 1,
#          'controlonly': 1,
#          'low': 4302,
#          'highlight': 558,
#          'role': 4421,
#          'cognitive': 2361,
#          'resources': 1153,
#          'targetdistractor': 1,
#          'selection': 1211,
#          'individualspecific': 1,
#          'cost': 1754,
#          'implications': 1213,
#          'such': 8164,
#          'genetic': 2143,
#          'environmental': 1793,
#          'known': 2171,
#          'development': 5945,
#          'childhood': 901,
#          'eczema': 137,
#          'our': 7658,
#          'aim': 2561,
#          'assess': 1905,
#          'associated': 8050,
#          'prevalence': 1735,
#          'webbased': 132,
#          'survey': 1545,
#          'june': 191,
#          '2012': 745,
#          'conducted': 2659,
#          'nationwide': 120,
#          'identify': 2207,
#          'characteristics': 2836,
#          'allergic': 432,
#          'diseases': 2194,
#          'japanese': 263,
#          'including': 4835,
#          'assessed': 2369,
#          'international': 897,
#          'asthma': 1032,
#          'allergies': 372,
#          'core': 777,
#          'associations': 1145,
#          'well': 5474,
#          'those': 3922,
#          'comorbid': 321,
#          '612': 39,
#          'old': 502,
#          'total': 3879,
#          '28348': 1,
#          '130': 104,
#          'significantly': 5811,
#          'wheeze': 31,
#          'rhinitis': 100,
#          'food': 1368,
#          'allergy': 492,
#          'multiple': 2711,
#          'logistic': 720,
#          'regression': 1700,
#          'birth': 793,
#          'during': 6701,
#          'autumn': 31,
#          'aor': 224,
#          '118': 113,
#          '95': 3629,
#          'ci': 3033,
#          '106131': 2,
#          'winter': 255,
#          '121': 112,
#          '108134': 1,
#          'duration': 1000,
#          'exclusive': 61,
#          'breastfeeding': 104,
#          'least': 1225,
#          '6': 1746,
#          'months': 2040,
#          '114': 103,
#          '106123': 1,
#          'ownership': 85,
#          'pet': 185,
#          'infancy': 73,
#          '261': 34,
#          '168407': 1,
#          'also': 10492,
#          'lower': 3595,
#          'annual': 371,
#          'household': 287,
#          'income': 297,
#          '090': 51,
#          '081099': 1,
#          '2': 4865,
#          'siblings': 93,
#          '086': 40,
#          '076097': 1,
#          'conclusions': 3195,
#          'season': 245,
#          'web': 507,
#          'copyright': 573,
#          'allergology': 24,
#          'production': 2074,
#          'hosting': 99,
#          'elsevier': 6946,
#          'bv': 2234,
#          'articular': 79,
#          'extraarticular': 16,
#          'manifestations': 204,
#          'hlab27': 22,
#          'undergone': 98,
#          'dramatic': 94,
#          'changes': 3353,
#          'past': 922,
#          'mainly': 947,
#          'consequence': 226,
#          'introduction': 879,
#          'biologic': 135,
#          'agents': 892,
#          'particular': 1532,
#          'antitumor': 124,
#          'necrosis': 280,
#          'antitnf': 125,
#          'alpha': 816,
#          'uveitis': 41,
#          'frequent': 615,
#          'feature': 954,
#          'hlab27associated': 2,
#          'spondyloarthritides': 4,
#          'topical': 197,
#          'corticosteroids': 113,
#          'cycloplegic': 1,
#          'remain': 610,
#          'cornerstones': 4,
#          'however': 6809,
#          'therapy': 2873,
#          'management': 3574,
#          'refractory': 141,
#          'recurrent': 330,
#          'review': 3416,
#          'gives': 271,
#          'update': 197,
#          'ocular': 99,
#          'disorders': 2795,
#          'biologics': 83,
#          'nonantitnf': 1,
#          'modifier': 14,
#          'drugs': 998,
#          'emerging': 630,
#          'newer': 69,
#          'targeting': 516,
#          'interleukin1223': 1,
#          'interleukin17': 3,
#          'anterior': 330,
#          'sparse': 295,
#          'resilience': 203,
#          'dynamic': 1830,
#          'multifaceted': 42,
#          'which': 15402,
#          'draw': 134,
#          'personal': 578,
#          'contextual': 164,
#          'difficult': 777,
#          'situations': 410,
#          'resilient': 57,
#          'use': 8512,
#          'specific': 2901,
#          'strategies': 2034,
#          'learn': 273,
#          'situation': 428,
#          'without': 3276,
#          'overcome': 445,
#          'stressors': 139,
#          'inherent': 217,
#          'veterinary': 69,
#          'work': 3528,
#          'hours': 445,
#          'ethical': 130,
#          'dilemmas': 27,
#          'challenging': 677,
#          'interactions': 1270,
#          'important': 4875,
#          'component': 1069,
#          'quality': 3782,
#          'life': 2836,
#          'other': 6850,
#          'professionals': 477,
#          'received': 1256,
#          'attention': 1539,
#          'little': 1051,
#          'field': 2488,
#          'crosssectional': 742,
#          'students': 2820,
#          'six': 934,
#          'schools': 300,
#          'australia': 210,
#          'completed': 1139,
#          'online': 1026,
#          '193': 52,
#          'responses': 1605,
#          '23': 553,
#          'very': 2032,
#          'few': 1233,
#          'reached': 294,
#          'threshold': 365,
#          'highly': 1756,
#          'approximately': 663,
#          'third': 528,
#          'classified': 485,
#          'having': 1071,
#          'levels': 6272,
#          'final': 605,
#          'linear': 1694,
#          'predictors': 575,
#          'nonjudgmental': 9,
#          'nonreactive': 6,
#          'mindfulness': 255,
#          'five': 1319,
#          'facet': 64,
#          'selfcompassion': 74,
#          'neff': 4,
#          'had': 5562,
#          'scores': 1656,
#          'these': 14319,
#          'findings': 4066,
#          'indicate': 1511,
#          'fostering': 31,
#          'qualities': 95,
#          'aligned': 55,
#          'strengthening': 97,
#          'student': 442,
#          'importantly': 274,
#          'if': 1845,
#          'help': 1478,
#          'identified': 3479,
#          'targeted': 639,
#          'educate': 50,
#          'future': 2368,
#          'cxcr4using': 1,
#          'hiv1': 121,
#          'previously': 1197,
#          'shown': 2081,
#          'replicate': 74,
#          'efficiently': 456,
#          'healthy': 2076,
#          'donorderived': 9,
#          'cd4': 261,
#          'cd38': 10,
#          'tcell': 227,
#          'subset': 318,
#          'after': 6769,
#          'stimulation': 577,
#          'interleukinil4': 1,
#          'here': 1986,
#          '3': 3539,
#          'cellular': 873,
#          'genes': 2428,
#          'expressed': 1185,
#          'level': 4020,
#          'il4stimulated': 1,
#          'rnf125trac1': 1,
#          'involved': 1705,
#          'downregulation': 150,
#          'replication': 297,
#          'cell': 4962,
#          'lines': 815,
#          'peripheral': 614,
#          'blood': 1982,
#          'mononuclear': 89,
#          'rnfi25trac1': 2,
#          'bears': 23,
#          'ring': 188,
#          'finger': 89,
#          'domain': 1085,
#          'e3': 18,
#          'ubiquitin': 29,
#          'protein': 3266,
#          'ligase': 18,
#          'mutations': 877,
#          'rnfl25trac1': 2,
#          'led': 769,
#          'loss': 1835,
#          'downmodulatory': 1,
#          'activity': 4204,
#          'necessary': 966,
#          'northern': 663,
#          'blotting': 1118,
#          'reporter': 151,
#          'gene': 3479,
#          'function': 3809,
#          'occurs': 427,
#          'viral': 598,
#          'transcription': 641,
#          'suggest': 2557,
#          'could': 3695,
#          'recruit': 44,
#          'host': 548,
#          'controlling': 609,
#          'ubiquitinproteasome': 7,
#          'pathway': 1121,
#          '2007': 246,
#          'inc': 1713,
#          'all': 13135,
#          'rights': 6266,
#          'reserved': 6155,
#          'cortana': 9,
#          'new': 6331,
#          'features': 2341,
#          'introduced': 889,
#          'microsoft': 35,
#          'windows': 132,
#          '10': 2209,
#          'desktop': 42,
#          'operating': 1102,
#          'systems': 5429,
#          'voice': 104,
#          'activated': 386,
#          'digital': 1158,
#          'assistant': 22,
#          'searching': 160,
#          'stuff': 5,
#          'device': 975,
#          'setting': 846,
#          'up': 1970,
#          'reminders': 25,
#          'tracking': 609,
#          'users': 1315,
#          'upcoming': 30,
#          'flights': 13,
#          'getting': 90,
#          'news': 113,
#          'tailored': 194,
#          'interests': 133,
#          'sending': 27,
#          'emails': 10,
#          'platform': 781,
#          'relatively': 878,
#          'forensic': 195,
#          'examination': 602,
#          'largely': 500,
#          'unexplored': 52,
#          'literature': 2083,
#          'paper': 8694,
#          'seeks': 99,
#          'determine': 2160,
#          'remnants': 13,
#          'usage': 529,
#          'pc': 156,
#          'contributes': 386,
#          'indepth': 211,
#          'location': 539,
#          'evidentiary': 5,
#          'artifacts': 102,
#          'hard': 224,
#          'disk': 120,
#          'type': 2692,
#          'information': 4714,
#          'recorded': 590,
#          'result': 1922,
#          'user': 841,
#          'activities': 1488,
#          'decoding': 54,
#          'exporting': 11,
#          'databases': 877,
#          'created': 461,
#          'application': 2555,
#          'custom': 97,
#          'python': 46,
#          'scripts': 30,
#          'developed': 3841,
#          'additionally': 798,
#          'gui': 35,
#          'tool': 1652,
#          'called': 713,
#          'cortanadigger': 1,
#          'extracting': 100,
#          'listing': 8,
#          'search': 1043,
#          'strings': 44,
#          'timestamp': 7,
#          'made': 1376,
#          'box': 185,
#          'track': 215,
#          'place': 460,
#          'person': 419,
#          'detect': 845,
#          'anti': 60,
#          'attempts': 320,
#          'like': 965,
#          'modification': 362,
#          'destruction': 98,
#          'carried': 1273,
#          'out': 2439,
#          'finally': 1666,
#          'usefulness': 168,
#          'demonstrated': 2281,
#          'terms': 1713,
#          'timeline': 6,
#          'constructed': 602,
#          'period': 1902,
#          'objective': 2695,
#          'examine': 1391,
#          'relationships': 1075,
#          'spirituality': 47,
#          'physical': 2705,
#          'sedentary': 91,
#          'behavior': 3166,
#          'sample': 2162,
#          'adults': 1401,
#          'massachusetts': 26,
#          'design': 6597,
#          'lawrence': 6,
#          'patients': 19196,
#          'family': 1926,
#          'glfhc': 1,
#          '602': 16,
#          'hispanic': 103,
#          'aged': 984,
#          '21': 575,
#          '85': 261,
#          'years': 5505,
#          'relationship': 2564,
#          'beta': 1139,
#          '12': 1820,
#          'p': 7255,
#          '004': 175,
#          'although': 2473,
#          'statistically': 752,
#          'increased': 5658,
#          'odds': 826,
#          'engaging': 127,
#          'men': 1906,
#          '005': 1052,
#          'who': 4377,
#          'spiritual': 62,
#          'association': 2698,
#          'stronger': 325,
#          'insight': 439,
#          'developing': 1339,
#          'interventions': 1457,
#          'promote': 600,
#          'highrisk': 201,
#          'greatly': 342,
#          'understudied': 54,
#          'endeavors': 10,
#          'should': 2698,
#          'consider': 727,
#          'investigating': 327,
#          'impact': 2950,
#          'spiritualitybased': 1,
#          'messages': 173,
#          'reduce': 1839,
#          'latinos': 38,
#          'objectiveimpairment': 1,
#          'frequently': 757,
#          'alzheimers': 469,
#          'disease': 6410,
#          'ad': 1253,
#          'cause': 1138,
#          'severe': 1336,
#          'constraints': 579,
#          'daily': 1151,
#          'nonverbal': 466,
#          'ravens': 2,
#          'colored': 32,
#          'progressive': 309,
#          'matrices': 220,
#          'rcpm': 6,
#          'test': 3379,
#          'consists': 596,
#          'sets': 607,
#          'ab': 119,
#          'b': 1722,
#          'performed': 3409,
#          'short': 846,
#          'evaluate': 2167,
#          'reasoning': 220,
#          'ability': 1651,
#          'purpose': 2013,
#          'neural': 1030,
#          'basis': 1156,
#          'singlephoton': 11,
#          'emission': 375,
#          'computed': 450,
#          'tomography': 335,
#          'spect': 27,
#          'methodsfifty': 3,
#          'fulfilled': 71,
#          'national': 1098,
#          'institute': 239,
#          'agingalzheimers': 1,
#          'criteria': 1464,
#          'probable': 134,
#          'dementia': 634,
#          'examined': 2273,
#          'spects': 1,
#          'nisopropylpi123iodoamphetamine': 1,
#          'perform': 659,
#          'multivariate': 629,
#          'analyses': 2236,
#          'regional': 327,
#          'cerebral': 304,
#          'rcbf': 12,
#          'resultsthere': 12,
#          'score': 1592,
#          'inferior': 144,
#          'parietal': 80,
#          'lobes': 35,
#          'bilaterally': 28,
#          'right': 612,
#          'temporal': 672,
#          'gyrus': 138,
#          ...})

# %%
VOCAB_SIZE = tokenizer.get_vocab_size()
VOCAB_SIZE
# Out:
# 158635

# %%
embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_SIZE))
embedding_matrix.shape
# Out:
# (158635, 300)

# %%
Word2Vec = gensim.models.KeyedVectors.load_word2vec_format('./test_models/GoogleNews-vectors-negative300.bin', binary=True)

# %% [markdown]
# ### для незнакомых слов либо !нулевой вектор! либо сумма контекстных

# %%
for index, word in zip(tokenizer.token2index.values(),tokenizer.token2index.keys()):
    try:
        embedding_matrix[index] = Word2Vec.get_vector(word).copy()
    except:
        embedding_matrix[index] = np.zeros(EMBEDDING_SIZE)

# %%
del Word2Vec

# %%
def vectorize(text):
    vector = np.zeros(EMBEDDING_SIZE)
    for token in tokenizer.encode(text).tokens:
        try:
            vector += embedding_matrix[tokenizer.token2index[token]]
        except:
            pass
    return vector

# %%
train_X = np.array([vectorize(text) for text in train_df.texts.to_list()])
test_X = np.array([vectorize(text) for text in test_df.texts.to_list()])

# %% [markdown]
# # MODEL

# %%
rfc = RandomForestClassifier(random_state=RANDOM_SEED,n_jobs=-1)

# %%
svc = SVC(random_state=RANDOM_SEED)

# %%
lgbm = lightgbm.LGBMClassifier(objective='multiclass', seed=RANDOM_SEED)

# %%
cbc = CatBoostClassifier(random_seed=RANDOM_SEED,task_type='GPU')

# %% [markdown]
# # TRAIN & PREDICT

# %% [markdown]
# ## Random Forest

# %%
rfc.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
# %%time
rfc.fit(train_X,train_df[target_column])
# Out:
# CPU times: total: 1min 53s
# Wall time: 10.2 s
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# %time
accuracy_score(rfc.predict(test_X),test_df[target_column])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 0.7097252676383335

# %%
print(classification_report(train_df[target_column],rfc.predict(train_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4364
#            1       1.00      1.00      1.00      3674
#            2       1.00      1.00      1.00      4785
#            3       1.00      1.00      1.00      2209
#            4       1.00      1.00      1.00      2839
#            5       1.00      1.00      1.00      9798
#            6       1.00      1.00      1.00      3810
#
#     accuracy                           1.00     31479
#    macro avg       1.00      1.00      1.00     31479
# weighted avg       1.00      1.00      1.00     31479

# %%
print(classification_report(test_df[target_column],rfc.predict(test_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73      2150
#            1       0.72      0.73      0.72      1809
#            2       0.73      0.62      0.67      2357
#            3       0.66      0.37      0.47      1088
#            4       0.69      0.60      0.64      1398
#            5       0.73      0.85      0.79      4827
#            6       0.68      0.64      0.66      1877
#
#     accuracy                           0.71     15506
#    macro avg       0.70      0.66      0.67     15506
# weighted avg       0.71      0.71      0.70     15506

# %% [markdown]
# ## LightGBM

# %%
lgbm.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': 'multiclass',
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': 'warn',
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'seed': 42}

# %%
# %%time
lgbm.fit(train_X, train_df[target_column])
# Out:
# CPU times: total: 2min 48s
# Wall time: 15.2 s
# LGBMClassifier(objective='multiclass', seed=42)

# %%
# %%time
accuracy_score(lgbm.predict(test_X),test_df[target_column])
# Out:
# CPU times: total: 2.06 s
# Wall time: 199 ms
# 0.7519669805236683

# %%
print(classification_report(train_df[target_column],lgbm.predict(train_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      4364
#            1       0.98      0.99      0.98      3674
#            2       0.96      0.92      0.94      4785
#            3       0.99      0.98      0.99      2209
#            4       0.98      0.98      0.98      2839
#            5       0.95      0.97      0.96      9798
#            6       0.96      0.95      0.96      3810
#
#     accuracy                           0.97     31479
#    macro avg       0.97      0.97      0.97     31479
# weighted avg       0.97      0.97      0.97     31479

# %%
print(classification_report(test_df[target_column],lgbm.predict(test_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77      2150
#            1       0.78      0.75      0.76      1809
#            2       0.75      0.70      0.72      2357
#            3       0.68      0.58      0.63      1088
#            4       0.74      0.71      0.72      1398
#            5       0.78      0.83      0.80      4827
#            6       0.70      0.71      0.70      1877
#
#     accuracy                           0.75     15506
#    macro avg       0.74      0.72      0.73     15506
# weighted avg       0.75      0.75      0.75     15506

# %% [markdown]
# ## CatBoost

# %%
cbc.get_all_params()
# Out:
# {'nan_mode': 'Min',
#  'gpu_ram_part': 0.95,
#  'eval_metric': 'MultiClass',
#  'iterations': 1000,
#  'leaf_estimation_method': 'Newton',
#  'observations_to_bootstrap': 'TestOnly',
#  'grow_policy': 'SymmetricTree',
#  'penalties_coefficient': 1,
#  'boosting_type': 'Plain',
#  'feature_border_type': 'GreedyLogSum',
#  'bayesian_matrix_reg': 0.10000000149011612,
#  'devices': '-1',
#  'eval_fraction': 0,
#  'pinned_memory_bytes': '104857600',
#  'force_unit_auto_pair_weights': False,
#  'l2_leaf_reg': 3,
#  'random_strength': 1,
#  'rsm': 1,
#  'boost_from_average': False,
#  'gpu_cat_features_storage': 'GpuRam',
#  'fold_size_loss_normalization': False,
#  'model_size_reg': 0.5,
#  'pool_metainfo_options': {'tags': {}},
#  'use_best_model': False,
#  'meta_l2_frequency': 0,
#  'class_names': [0, 1, 2, 3, 4, 5, 6],
#  'random_seed': 42,
#  'depth': 6,
#  'border_count': 128,
#  'min_fold_size': 100,
#  'data_partition': 'DocParallel',
#  'bagging_temperature': 1,
#  'classes_count': 0,
#  'auto_class_weights': 'None',
#  'leaf_estimation_backtracking': 'AnyImprovement',
#  'best_model_min_trees': 1,
#  'min_data_in_leaf': 1,
#  'add_ridge_penalty_to_loss_function': False,
#  'loss_function': 'MultiClass',
#  'learning_rate': 0.13118399679660797,
#  'meta_l2_exponent': 1,
#  'score_function': 'Cosine',
#  'task_type': 'GPU',
#  'leaf_estimation_iterations': 1,
#  'bootstrap_type': 'Bayesian',
#  'max_leaves': 64}

# %%
# %%time
cbc.fit(train_X, train_df[target_column])
# Out:
# Learning rate set to 0.131184
# 0:	learn: 1.7293913	total: 44.7ms	remaining: 44.7s
# 1:	learn: 1.5951490	total: 68.9ms	remaining: 34.4s
# 2:	learn: 1.4931727	total: 94.6ms	remaining: 31.4s
# 3:	learn: 1.4141670	total: 121ms	remaining: 30.1s
# 4:	learn: 1.3470368	total: 145ms	remaining: 28.9s
# 5:	learn: 1.2904635	total: 167ms	remaining: 27.7s
# 6:	learn: 1.2426206	total: 190ms	remaining: 27s
# 7:	learn: 1.2030093	total: 213ms	remaining: 26.4s
# 8:	learn: 1.1684087	total: 236ms	remaining: 26s
# 9:	learn: 1.1365850	total: 259ms	remaining: 25.7s
# 10:	learn: 1.1081118	total: 281ms	remaining: 25.2s
# 11:	learn: 1.0834571	total: 301ms	remaining: 24.8s
# 12:	learn: 1.0618205	total: 323ms	remaining: 24.5s
# 13:	learn: 1.0413361	total: 344ms	remaining: 24.2s
# 14:	learn: 1.0235205	total: 366ms	remaining: 24s
# 15:	learn: 1.0072728	total: 387ms	remaining: 23.8s
# 16:	learn: 0.9927364	total: 407ms	remaining: 23.6s
# 17:	learn: 0.9783739	total: 429ms	remaining: 23.4s
# 18:	learn: 0.9658506	total: 452ms	remaining: 23.3s
# 19:	learn: 0.9538380	total: 473ms	remaining: 23.2s
# 20:	learn: 0.9436667	total: 494ms	remaining: 23s
# 21:	learn: 0.9338533	total: 514ms	remaining: 22.9s
# 22:	learn: 0.9232203	total: 536ms	remaining: 22.8s
# 23:	learn: 0.9133423	total: 558ms	remaining: 22.7s
# 24:	learn: 0.9047963	total: 580ms	remaining: 22.6s
# 25:	learn: 0.8964720	total: 603ms	remaining: 22.6s
# 26:	learn: 0.8886009	total: 626ms	remaining: 22.6s
# 27:	learn: 0.8813243	total: 649ms	remaining: 22.5s
# 28:	learn: 0.8745075	total: 672ms	remaining: 22.5s
# 29:	learn: 0.8679642	total: 696ms	remaining: 22.5s
# 30:	learn: 0.8624814	total: 718ms	remaining: 22.4s
# 31:	learn: 0.8565518	total: 741ms	remaining: 22.4s
# 32:	learn: 0.8512051	total: 763ms	remaining: 22.4s
# 33:	learn: 0.8456878	total: 784ms	remaining: 22.3s
# 34:	learn: 0.8401342	total: 805ms	remaining: 22.2s
# 35:	learn: 0.8351475	total: 826ms	remaining: 22.1s
# 36:	learn: 0.8306011	total: 847ms	remaining: 22s
# 37:	learn: 0.8249990	total: 868ms	remaining: 22s
# 38:	learn: 0.8203968	total: 889ms	remaining: 21.9s
# 39:	learn: 0.8152221	total: 910ms	remaining: 21.8s
# 40:	learn: 0.8108801	total: 930ms	remaining: 21.8s
# 41:	learn: 0.8067135	total: 951ms	remaining: 21.7s
# 42:	learn: 0.8029099	total: 972ms	remaining: 21.6s
# 43:	learn: 0.7988968	total: 993ms	remaining: 21.6s
# 44:	learn: 0.7944662	total: 1.01s	remaining: 21.5s
# 45:	learn: 0.7899126	total: 1.03s	remaining: 21.5s
# 46:	learn: 0.7863975	total: 1.05s	remaining: 21.4s
# 47:	learn: 0.7832405	total: 1.07s	remaining: 21.3s
# 48:	learn: 0.7801303	total: 1.1s	remaining: 21.3s
# 49:	learn: 0.7761583	total: 1.12s	remaining: 21.3s
# 50:	learn: 0.7734918	total: 1.14s	remaining: 21.2s
# 51:	learn: 0.7702698	total: 1.16s	remaining: 21.1s
# 52:	learn: 0.7671585	total: 1.18s	remaining: 21.1s
# 53:	learn: 0.7642387	total: 1.2s	remaining: 21s
# 54:	learn: 0.7611755	total: 1.22s	remaining: 21s
# 55:	learn: 0.7578979	total: 1.24s	remaining: 21s
# 56:	learn: 0.7551018	total: 1.26s	remaining: 20.9s
# 57:	learn: 0.7527288	total: 1.28s	remaining: 20.8s
# 58:	learn: 0.7502193	total: 1.3s	remaining: 20.8s
# 59:	learn: 0.7476382	total: 1.32s	remaining: 20.7s
# 60:	learn: 0.7452551	total: 1.34s	remaining: 20.7s
# 61:	learn: 0.7419549	total: 1.36s	remaining: 20.7s
# 62:	learn: 0.7391868	total: 1.39s	remaining: 20.6s
# 63:	learn: 0.7364417	total: 1.41s	remaining: 20.6s
# 64:	learn: 0.7339229	total: 1.43s	remaining: 20.5s
# 65:	learn: 0.7315603	total: 1.45s	remaining: 20.5s
# 66:	learn: 0.7298379	total: 1.47s	remaining: 20.4s
# 67:	learn: 0.7275759	total: 1.49s	remaining: 20.4s
# 68:	learn: 0.7253193	total: 1.51s	remaining: 20.3s
# 69:	learn: 0.7232464	total: 1.53s	remaining: 20.3s
# 70:	learn: 0.7207630	total: 1.55s	remaining: 20.3s
# 71:	learn: 0.7190361	total: 1.57s	remaining: 20.2s
# 72:	learn: 0.7166393	total: 1.59s	remaining: 20.2s
# 73:	learn: 0.7138681	total: 1.61s	remaining: 20.2s
# 74:	learn: 0.7118783	total: 1.63s	remaining: 20.1s
# 75:	learn: 0.7104378	total: 1.65s	remaining: 20.1s
# 76:	learn: 0.7084397	total: 1.67s	remaining: 20.1s
# 77:	learn: 0.7058666	total: 1.69s	remaining: 20s
# 78:	learn: 0.7036219	total: 1.71s	remaining: 20s
# 79:	learn: 0.7014771	total: 1.73s	remaining: 19.9s
# 80:	learn: 0.6989932	total: 1.75s	remaining: 19.9s
# 81:	learn: 0.6973567	total: 1.78s	remaining: 19.9s
# 82:	learn: 0.6953609	total: 1.8s	remaining: 19.8s
# 83:	learn: 0.6934003	total: 1.82s	remaining: 19.8s
# 84:	learn: 0.6916469	total: 1.84s	remaining: 19.8s
# 85:	learn: 0.6895861	total: 1.86s	remaining: 19.7s
# 86:	learn: 0.6872121	total: 1.88s	remaining: 19.7s
# 87:	learn: 0.6856928	total: 1.9s	remaining: 19.7s
# 88:	learn: 0.6841459	total: 1.92s	remaining: 19.6s
# 89:	learn: 0.6821809	total: 1.94s	remaining: 19.6s
# 90:	learn: 0.6805072	total: 1.96s	remaining: 19.6s
# 91:	learn: 0.6787155	total: 1.98s	remaining: 19.6s
# 92:	learn: 0.6771814	total: 2s	remaining: 19.5s
# 93:	learn: 0.6751231	total: 2.03s	remaining: 19.5s
# 94:	learn: 0.6733200	total: 2.05s	remaining: 19.5s
# 95:	learn: 0.6710643	total: 2.07s	remaining: 19.5s
# 96:	learn: 0.6694308	total: 2.09s	remaining: 19.5s
# 97:	learn: 0.6681343	total: 2.12s	remaining: 19.5s
# 98:	learn: 0.6662170	total: 2.14s	remaining: 19.5s
# 99:	learn: 0.6645992	total: 2.16s	remaining: 19.4s
# 100:	learn: 0.6628487	total: 2.18s	remaining: 19.4s
# 101:	learn: 0.6612715	total: 2.2s	remaining: 19.4s
# 102:	learn: 0.6593448	total: 2.22s	remaining: 19.4s
# 103:	learn: 0.6573852	total: 2.24s	remaining: 19.3s
# 104:	learn: 0.6557889	total: 2.26s	remaining: 19.3s
# 105:	learn: 0.6541673	total: 2.29s	remaining: 19.3s
# 106:	learn: 0.6527174	total: 2.31s	remaining: 19.2s
# 107:	learn: 0.6511414	total: 2.32s	remaining: 19.2s
# 108:	learn: 0.6493279	total: 2.35s	remaining: 19.2s
# 109:	learn: 0.6481021	total: 2.37s	remaining: 19.1s
# 110:	learn: 0.6461517	total: 2.39s	remaining: 19.1s
# 111:	learn: 0.6447892	total: 2.41s	remaining: 19.1s
# 112:	learn: 0.6431762	total: 2.43s	remaining: 19.1s
# 113:	learn: 0.6416927	total: 2.45s	remaining: 19s
# 114:	learn: 0.6400809	total: 2.47s	remaining: 19s
# 115:	learn: 0.6384924	total: 2.49s	remaining: 19s
# 116:	learn: 0.6372943	total: 2.51s	remaining: 18.9s
# 117:	learn: 0.6358752	total: 2.53s	remaining: 18.9s
# 118:	learn: 0.6347404	total: 2.55s	remaining: 18.9s
# 119:	learn: 0.6334494	total: 2.57s	remaining: 18.9s
# 120:	learn: 0.6321413	total: 2.59s	remaining: 18.8s
# 121:	learn: 0.6308684	total: 2.61s	remaining: 18.8s
# 122:	learn: 0.6296386	total: 2.63s	remaining: 18.8s
# 123:	learn: 0.6285418	total: 2.65s	remaining: 18.8s
# 124:	learn: 0.6275403	total: 2.67s	remaining: 18.7s
# 125:	learn: 0.6260901	total: 2.69s	remaining: 18.7s
# 126:	learn: 0.6248224	total: 2.71s	remaining: 18.7s
# 127:	learn: 0.6232073	total: 2.74s	remaining: 18.6s
# 128:	learn: 0.6218606	total: 2.76s	remaining: 18.6s
# 129:	learn: 0.6205306	total: 2.78s	remaining: 18.6s
# 130:	learn: 0.6197307	total: 2.8s	remaining: 18.6s
# 131:	learn: 0.6185717	total: 2.82s	remaining: 18.5s
# 132:	learn: 0.6174387	total: 2.84s	remaining: 18.5s
# 133:	learn: 0.6160177	total: 2.86s	remaining: 18.5s
# 134:	learn: 0.6145191	total: 2.88s	remaining: 18.5s
# 135:	learn: 0.6135278	total: 2.9s	remaining: 18.4s
# 136:	learn: 0.6124721	total: 2.92s	remaining: 18.4s
# 137:	learn: 0.6109930	total: 2.94s	remaining: 18.4s
# 138:	learn: 0.6100244	total: 2.96s	remaining: 18.4s
# 139:	learn: 0.6088369	total: 2.98s	remaining: 18.3s
# 140:	learn: 0.6074631	total: 3s	remaining: 18.3s
# 141:	learn: 0.6060574	total: 3.03s	remaining: 18.3s
# 142:	learn: 0.6052308	total: 3.05s	remaining: 18.3s
# 143:	learn: 0.6041390	total: 3.07s	remaining: 18.2s
# 144:	learn: 0.6031623	total: 3.09s	remaining: 18.2s
# 145:	learn: 0.6017001	total: 3.11s	remaining: 18.2s
# 146:	learn: 0.6003311	total: 3.13s	remaining: 18.2s
# 147:	learn: 0.5988476	total: 3.15s	remaining: 18.1s
# 148:	learn: 0.5978323	total: 3.17s	remaining: 18.1s
# 149:	learn: 0.5966650	total: 3.19s	remaining: 18.1s
# 150:	learn: 0.5952887	total: 3.21s	remaining: 18.1s
# 151:	learn: 0.5936204	total: 3.24s	remaining: 18.1s
# 152:	learn: 0.5927745	total: 3.26s	remaining: 18s
# 153:	learn: 0.5915447	total: 3.28s	remaining: 18s
# 154:	learn: 0.5901526	total: 3.3s	remaining: 18s
# 155:	learn: 0.5891251	total: 3.32s	remaining: 18s
# 156:	learn: 0.5881855	total: 3.34s	remaining: 17.9s
# 157:	learn: 0.5871756	total: 3.36s	remaining: 17.9s
# 158:	learn: 0.5858163	total: 3.38s	remaining: 17.9s
# 159:	learn: 0.5845281	total: 3.41s	remaining: 17.9s
# 160:	learn: 0.5828431	total: 3.43s	remaining: 17.9s
# 161:	learn: 0.5814717	total: 3.45s	remaining: 17.8s
# 162:	learn: 0.5804585	total: 3.47s	remaining: 17.8s
# 163:	learn: 0.5794491	total: 3.49s	remaining: 17.8s
# 164:	learn: 0.5782084	total: 3.51s	remaining: 17.8s
# 165:	learn: 0.5774911	total: 3.54s	remaining: 17.8s
# 166:	learn: 0.5765476	total: 3.56s	remaining: 17.8s
# 167:	learn: 0.5756012	total: 3.58s	remaining: 17.7s
# 168:	learn: 0.5744853	total: 3.6s	remaining: 17.7s
# 169:	learn: 0.5733695	total: 3.62s	remaining: 17.7s
# 170:	learn: 0.5725572	total: 3.64s	remaining: 17.7s
# 171:	learn: 0.5715322	total: 3.66s	remaining: 17.6s
# 172:	learn: 0.5707574	total: 3.68s	remaining: 17.6s
# 173:	learn: 0.5696788	total: 3.7s	remaining: 17.6s
# 174:	learn: 0.5687518	total: 3.73s	remaining: 17.6s
# 175:	learn: 0.5678111	total: 3.75s	remaining: 17.5s
# 176:	learn: 0.5667029	total: 3.77s	remaining: 17.5s
# 177:	learn: 0.5654817	total: 3.79s	remaining: 17.5s
# 178:	learn: 0.5648621	total: 3.81s	remaining: 17.5s
# 179:	learn: 0.5640882	total: 3.83s	remaining: 17.4s
# 180:	learn: 0.5631322	total: 3.85s	remaining: 17.4s
# 181:	learn: 0.5617487	total: 3.87s	remaining: 17.4s
# 182:	learn: 0.5604675	total: 3.89s	remaining: 17.4s
# 183:	learn: 0.5592664	total: 3.91s	remaining: 17.4s
# 184:	learn: 0.5581784	total: 3.93s	remaining: 17.3s
# 185:	learn: 0.5568699	total: 3.96s	remaining: 17.3s
# 186:	learn: 0.5561942	total: 3.98s	remaining: 17.3s
# 187:	learn: 0.5549519	total: 4s	remaining: 17.3s
# 188:	learn: 0.5539001	total: 4.02s	remaining: 17.2s
# 189:	learn: 0.5532767	total: 4.04s	remaining: 17.2s
# 190:	learn: 0.5521284	total: 4.06s	remaining: 17.2s
# 191:	learn: 0.5512028	total: 4.08s	remaining: 17.2s
# 192:	learn: 0.5501141	total: 4.11s	remaining: 17.2s
# 193:	learn: 0.5493187	total: 4.13s	remaining: 17.2s
# 194:	learn: 0.5482945	total: 4.15s	remaining: 17.1s
# 195:	learn: 0.5475480	total: 4.17s	remaining: 17.1s
# 196:	learn: 0.5463038	total: 4.2s	remaining: 17.1s
# 197:	learn: 0.5455426	total: 4.22s	remaining: 17.1s
# 198:	learn: 0.5449104	total: 4.24s	remaining: 17.1s
# 199:	learn: 0.5437997	total: 4.26s	remaining: 17s
# 200:	learn: 0.5428339	total: 4.28s	remaining: 17s
# 201:	learn: 0.5415900	total: 4.3s	remaining: 17s
# 202:	learn: 0.5408392	total: 4.32s	remaining: 17s
# 203:	learn: 0.5399914	total: 4.34s	remaining: 16.9s
# 204:	learn: 0.5384465	total: 4.36s	remaining: 16.9s
# 205:	learn: 0.5377576	total: 4.38s	remaining: 16.9s
# 206:	learn: 0.5368020	total: 4.41s	remaining: 16.9s
# 207:	learn: 0.5357129	total: 4.43s	remaining: 16.9s
# 208:	learn: 0.5346582	total: 4.45s	remaining: 16.9s
# 209:	learn: 0.5337221	total: 4.47s	remaining: 16.8s
# 210:	learn: 0.5327201	total: 4.5s	remaining: 16.8s
# 211:	learn: 0.5320156	total: 4.52s	remaining: 16.8s
# 212:	learn: 0.5312848	total: 4.54s	remaining: 16.8s
# 213:	learn: 0.5304743	total: 4.56s	remaining: 16.7s
# 214:	learn: 0.5299175	total: 4.58s	remaining: 16.7s
# 215:	learn: 0.5291674	total: 4.6s	remaining: 16.7s
# 216:	learn: 0.5284809	total: 4.62s	remaining: 16.7s
# 217:	learn: 0.5276231	total: 4.64s	remaining: 16.6s
# 218:	learn: 0.5265937	total: 4.66s	remaining: 16.6s
# 219:	learn: 0.5255520	total: 4.68s	remaining: 16.6s
# 220:	learn: 0.5245170	total: 4.7s	remaining: 16.6s
# 221:	learn: 0.5237662	total: 4.72s	remaining: 16.5s
# 222:	learn: 0.5231347	total: 4.74s	remaining: 16.5s
# 223:	learn: 0.5217456	total: 4.76s	remaining: 16.5s
# 224:	learn: 0.5211171	total: 4.78s	remaining: 16.5s
# 225:	learn: 0.5204823	total: 4.8s	remaining: 16.4s
# 226:	learn: 0.5198776	total: 4.82s	remaining: 16.4s
# 227:	learn: 0.5189404	total: 4.84s	remaining: 16.4s
# 228:	learn: 0.5182131	total: 4.86s	remaining: 16.4s
# 229:	learn: 0.5176044	total: 4.88s	remaining: 16.3s
# 230:	learn: 0.5168661	total: 4.9s	remaining: 16.3s
# 231:	learn: 0.5162164	total: 4.92s	remaining: 16.3s
# 232:	learn: 0.5154060	total: 4.95s	remaining: 16.3s
# 233:	learn: 0.5147965	total: 4.97s	remaining: 16.3s
# 234:	learn: 0.5134718	total: 4.99s	remaining: 16.2s
# 235:	learn: 0.5124992	total: 5.01s	remaining: 16.2s
# 236:	learn: 0.5116188	total: 5.03s	remaining: 16.2s
# 237:	learn: 0.5106487	total: 5.05s	remaining: 16.2s
# 238:	learn: 0.5097022	total: 5.07s	remaining: 16.1s
# 239:	learn: 0.5089547	total: 5.09s	remaining: 16.1s
# 240:	learn: 0.5079628	total: 5.12s	remaining: 16.1s
# 241:	learn: 0.5071875	total: 5.14s	remaining: 16.1s
# 242:	learn: 0.5064520	total: 5.16s	remaining: 16.1s
# 243:	learn: 0.5056518	total: 5.18s	remaining: 16.1s
# 244:	learn: 0.5049799	total: 5.2s	remaining: 16s
# 245:	learn: 0.5039177	total: 5.23s	remaining: 16s
# 246:	learn: 0.5031203	total: 5.25s	remaining: 16s
# 247:	learn: 0.5023418	total: 5.27s	remaining: 16s
# 248:	learn: 0.5017305	total: 5.29s	remaining: 16s
# 249:	learn: 0.5006531	total: 5.31s	remaining: 15.9s
# 250:	learn: 0.4995262	total: 5.33s	remaining: 15.9s
# 251:	learn: 0.4989838	total: 5.35s	remaining: 15.9s
# 252:	learn: 0.4983246	total: 5.37s	remaining: 15.9s
# 253:	learn: 0.4975516	total: 5.39s	remaining: 15.8s
# 254:	learn: 0.4966420	total: 5.42s	remaining: 15.8s
# 255:	learn: 0.4954798	total: 5.44s	remaining: 15.8s
# 256:	learn: 0.4948909	total: 5.46s	remaining: 15.8s
# 257:	learn: 0.4941680	total: 5.48s	remaining: 15.8s
# 258:	learn: 0.4931076	total: 5.5s	remaining: 15.7s
# 259:	learn: 0.4923380	total: 5.52s	remaining: 15.7s
# 260:	learn: 0.4917090	total: 5.54s	remaining: 15.7s
# 261:	learn: 0.4911266	total: 5.57s	remaining: 15.7s
# 262:	learn: 0.4903221	total: 5.59s	remaining: 15.7s
# 263:	learn: 0.4897946	total: 5.61s	remaining: 15.6s
# 264:	learn: 0.4889176	total: 5.63s	remaining: 15.6s
# 265:	learn: 0.4880991	total: 5.66s	remaining: 15.6s
# 266:	learn: 0.4872776	total: 5.68s	remaining: 15.6s
# 267:	learn: 0.4862346	total: 5.7s	remaining: 15.6s
# 268:	learn: 0.4855674	total: 5.72s	remaining: 15.6s
# 269:	learn: 0.4847321	total: 5.75s	remaining: 15.5s
# 270:	learn: 0.4839507	total: 5.77s	remaining: 15.5s
# 271:	learn: 0.4832411	total: 5.79s	remaining: 15.5s
# 272:	learn: 0.4824846	total: 5.81s	remaining: 15.5s
# 273:	learn: 0.4816314	total: 5.83s	remaining: 15.4s
# 274:	learn: 0.4805553	total: 5.85s	remaining: 15.4s
# 275:	learn: 0.4797547	total: 5.87s	remaining: 15.4s
# 276:	learn: 0.4791890	total: 5.89s	remaining: 15.4s
# 277:	learn: 0.4783356	total: 5.91s	remaining: 15.4s
# 278:	learn: 0.4773798	total: 5.93s	remaining: 15.3s
# 279:	learn: 0.4764452	total: 5.95s	remaining: 15.3s
# 280:	learn: 0.4758139	total: 5.97s	remaining: 15.3s
# 281:	learn: 0.4749447	total: 6s	remaining: 15.3s
# 282:	learn: 0.4740732	total: 6.02s	remaining: 15.2s
# 283:	learn: 0.4733463	total: 6.04s	remaining: 15.2s
# 284:	learn: 0.4727577	total: 6.06s	remaining: 15.2s
# 285:	learn: 0.4719492	total: 6.08s	remaining: 15.2s
# 286:	learn: 0.4714819	total: 6.1s	remaining: 15.2s
# 287:	learn: 0.4708414	total: 6.12s	remaining: 15.1s
# 288:	learn: 0.4701014	total: 6.14s	remaining: 15.1s
# 289:	learn: 0.4688917	total: 6.16s	remaining: 15.1s
# 290:	learn: 0.4682237	total: 6.18s	remaining: 15.1s
# 291:	learn: 0.4674110	total: 6.21s	remaining: 15s
# 292:	learn: 0.4666084	total: 6.23s	remaining: 15s
# 293:	learn: 0.4655118	total: 6.25s	remaining: 15s
# 294:	learn: 0.4649732	total: 6.27s	remaining: 15s
# 295:	learn: 0.4643512	total: 6.29s	remaining: 15s
# 296:	learn: 0.4635455	total: 6.31s	remaining: 14.9s
# 297:	learn: 0.4628829	total: 6.33s	remaining: 14.9s
# 298:	learn: 0.4620328	total: 6.36s	remaining: 14.9s
# 299:	learn: 0.4615235	total: 6.38s	remaining: 14.9s
# 300:	learn: 0.4609547	total: 6.4s	remaining: 14.9s
# 301:	learn: 0.4600977	total: 6.42s	remaining: 14.8s
# 302:	learn: 0.4595431	total: 6.44s	remaining: 14.8s
# 303:	learn: 0.4589317	total: 6.46s	remaining: 14.8s
# 304:	learn: 0.4584644	total: 6.48s	remaining: 14.8s
# 305:	learn: 0.4574205	total: 6.5s	remaining: 14.8s
# 306:	learn: 0.4566676	total: 6.53s	remaining: 14.7s
# 307:	learn: 0.4560926	total: 6.55s	remaining: 14.7s
# 308:	learn: 0.4556586	total: 6.57s	remaining: 14.7s
# 309:	learn: 0.4551561	total: 6.59s	remaining: 14.7s
# 310:	learn: 0.4543008	total: 6.61s	remaining: 14.6s
# 311:	learn: 0.4531800	total: 6.63s	remaining: 14.6s
# 312:	learn: 0.4524738	total: 6.65s	remaining: 14.6s
# 313:	learn: 0.4516179	total: 6.67s	remaining: 14.6s
# 314:	learn: 0.4508806	total: 6.69s	remaining: 14.6s
# 315:	learn: 0.4502658	total: 6.71s	remaining: 14.5s
# 316:	learn: 0.4494178	total: 6.73s	remaining: 14.5s
# 317:	learn: 0.4485180	total: 6.75s	remaining: 14.5s
# 318:	learn: 0.4480484	total: 6.78s	remaining: 14.5s
# 319:	learn: 0.4475441	total: 6.79s	remaining: 14.4s
# 320:	learn: 0.4471195	total: 6.81s	remaining: 14.4s
# 321:	learn: 0.4464390	total: 6.83s	remaining: 14.4s
# 322:	learn: 0.4456512	total: 6.85s	remaining: 14.4s
# 323:	learn: 0.4453303	total: 6.87s	remaining: 14.3s
# 324:	learn: 0.4449296	total: 6.89s	remaining: 14.3s
# 325:	learn: 0.4443319	total: 6.91s	remaining: 14.3s
# 326:	learn: 0.4437409	total: 6.93s	remaining: 14.3s
# 327:	learn: 0.4429310	total: 6.96s	remaining: 14.3s
# 328:	learn: 0.4423370	total: 6.98s	remaining: 14.2s
# 329:	learn: 0.4413082	total: 7s	remaining: 14.2s
# 330:	learn: 0.4405871	total: 7.02s	remaining: 14.2s
# 331:	learn: 0.4402182	total: 7.04s	remaining: 14.2s
# 332:	learn: 0.4395163	total: 7.06s	remaining: 14.1s
# 333:	learn: 0.4389259	total: 7.08s	remaining: 14.1s
# 334:	learn: 0.4383750	total: 7.1s	remaining: 14.1s
# 335:	learn: 0.4380088	total: 7.12s	remaining: 14.1s
# 336:	learn: 0.4374646	total: 7.14s	remaining: 14s
# 337:	learn: 0.4367813	total: 7.16s	remaining: 14s
# 338:	learn: 0.4362966	total: 7.18s	remaining: 14s
# 339:	learn: 0.4355715	total: 7.2s	remaining: 14s
# 340:	learn: 0.4350620	total: 7.22s	remaining: 14s
# 341:	learn: 0.4343742	total: 7.25s	remaining: 13.9s
# 342:	learn: 0.4339910	total: 7.27s	remaining: 13.9s
# 343:	learn: 0.4331110	total: 7.29s	remaining: 13.9s
# 344:	learn: 0.4320253	total: 7.31s	remaining: 13.9s
# 345:	learn: 0.4313426	total: 7.33s	remaining: 13.9s
# 346:	learn: 0.4307761	total: 7.36s	remaining: 13.8s
# 347:	learn: 0.4300645	total: 7.38s	remaining: 13.8s
# 348:	learn: 0.4294941	total: 7.4s	remaining: 13.8s
# 349:	learn: 0.4286677	total: 7.42s	remaining: 13.8s
# 350:	learn: 0.4282684	total: 7.44s	remaining: 13.8s
# 351:	learn: 0.4272258	total: 7.46s	remaining: 13.7s
# 352:	learn: 0.4268320	total: 7.48s	remaining: 13.7s
# 353:	learn: 0.4263769	total: 7.5s	remaining: 13.7s
# 354:	learn: 0.4257660	total: 7.53s	remaining: 13.7s
# 355:	learn: 0.4252694	total: 7.55s	remaining: 13.7s
# 356:	learn: 0.4245011	total: 7.57s	remaining: 13.6s
# 357:	learn: 0.4240260	total: 7.59s	remaining: 13.6s
# 358:	learn: 0.4230722	total: 7.61s	remaining: 13.6s
# 359:	learn: 0.4223348	total: 7.63s	remaining: 13.6s
# 360:	learn: 0.4220498	total: 7.65s	remaining: 13.5s
# 361:	learn: 0.4215181	total: 7.67s	remaining: 13.5s
# 362:	learn: 0.4210687	total: 7.7s	remaining: 13.5s
# 363:	learn: 0.4207599	total: 7.72s	remaining: 13.5s
# 364:	learn: 0.4203456	total: 7.74s	remaining: 13.5s
# 365:	learn: 0.4196688	total: 7.76s	remaining: 13.4s
# 366:	learn: 0.4191767	total: 7.78s	remaining: 13.4s
# 367:	learn: 0.4181132	total: 7.8s	remaining: 13.4s
# 368:	learn: 0.4175240	total: 7.82s	remaining: 13.4s
# 369:	learn: 0.4167434	total: 7.84s	remaining: 13.4s
# 370:	learn: 0.4161618	total: 7.86s	remaining: 13.3s
# 371:	learn: 0.4156530	total: 7.88s	remaining: 13.3s
# 372:	learn: 0.4151561	total: 7.9s	remaining: 13.3s
# 373:	learn: 0.4146759	total: 7.92s	remaining: 13.3s
# 374:	learn: 0.4142136	total: 7.94s	remaining: 13.2s
# 375:	learn: 0.4135628	total: 7.96s	remaining: 13.2s
# 376:	learn: 0.4131496	total: 7.99s	remaining: 13.2s
# 377:	learn: 0.4124872	total: 8.01s	remaining: 13.2s
# 378:	learn: 0.4120686	total: 8.03s	remaining: 13.2s
# 379:	learn: 0.4114857	total: 8.05s	remaining: 13.1s
# 380:	learn: 0.4110088	total: 8.07s	remaining: 13.1s
# 381:	learn: 0.4104133	total: 8.09s	remaining: 13.1s
# 382:	learn: 0.4100206	total: 8.11s	remaining: 13.1s
# 383:	learn: 0.4093257	total: 8.13s	remaining: 13s
# 384:	learn: 0.4088369	total: 8.15s	remaining: 13s
# 385:	learn: 0.4081817	total: 8.17s	remaining: 13s
# 386:	learn: 0.4077131	total: 8.19s	remaining: 13s
# 387:	learn: 0.4071190	total: 8.21s	remaining: 13s
# 388:	learn: 0.4065449	total: 8.24s	remaining: 12.9s
# 389:	learn: 0.4059132	total: 8.26s	remaining: 12.9s
# 390:	learn: 0.4056101	total: 8.28s	remaining: 12.9s
# 391:	learn: 0.4048000	total: 8.3s	remaining: 12.9s
# 392:	learn: 0.4043679	total: 8.32s	remaining: 12.9s
# 393:	learn: 0.4036296	total: 8.34s	remaining: 12.8s
# 394:	learn: 0.4032433	total: 8.36s	remaining: 12.8s
# 395:	learn: 0.4027223	total: 8.38s	remaining: 12.8s
# 396:	learn: 0.4020399	total: 8.4s	remaining: 12.8s
# 397:	learn: 0.4017260	total: 8.42s	remaining: 12.7s
# 398:	learn: 0.4010755	total: 8.44s	remaining: 12.7s
# 399:	learn: 0.4005354	total: 8.46s	remaining: 12.7s
# 400:	learn: 0.3997955	total: 8.49s	remaining: 12.7s
# 401:	learn: 0.3993410	total: 8.51s	remaining: 12.7s
# 402:	learn: 0.3990144	total: 8.53s	remaining: 12.6s
# 403:	learn: 0.3983187	total: 8.55s	remaining: 12.6s
# 404:	learn: 0.3977452	total: 8.57s	remaining: 12.6s
# 405:	learn: 0.3970762	total: 8.59s	remaining: 12.6s
# 406:	learn: 0.3966123	total: 8.61s	remaining: 12.5s
# 407:	learn: 0.3964087	total: 8.63s	remaining: 12.5s
# 408:	learn: 0.3957332	total: 8.65s	remaining: 12.5s
# 409:	learn: 0.3953240	total: 8.67s	remaining: 12.5s
# 410:	learn: 0.3949456	total: 8.69s	remaining: 12.4s
# 411:	learn: 0.3944468	total: 8.71s	remaining: 12.4s
# 412:	learn: 0.3940831	total: 8.73s	remaining: 12.4s
# 413:	learn: 0.3935431	total: 8.75s	remaining: 12.4s
# 414:	learn: 0.3929573	total: 8.77s	remaining: 12.4s
# 415:	learn: 0.3926762	total: 8.79s	remaining: 12.3s
# 416:	learn: 0.3922221	total: 8.81s	remaining: 12.3s
# 417:	learn: 0.3915561	total: 8.83s	remaining: 12.3s
# 418:	learn: 0.3911250	total: 8.85s	remaining: 12.3s
# 419:	learn: 0.3903880	total: 8.87s	remaining: 12.3s
# 420:	learn: 0.3895597	total: 8.89s	remaining: 12.2s
# 421:	learn: 0.3891341	total: 8.91s	remaining: 12.2s
# 422:	learn: 0.3887528	total: 8.93s	remaining: 12.2s
# 423:	learn: 0.3879673	total: 8.95s	remaining: 12.2s
# 424:	learn: 0.3874579	total: 8.97s	remaining: 12.1s
# 425:	learn: 0.3870627	total: 9s	remaining: 12.1s
# 426:	learn: 0.3865567	total: 9.02s	remaining: 12.1s
# 427:	learn: 0.3861654	total: 9.04s	remaining: 12.1s
# 428:	learn: 0.3857734	total: 9.06s	remaining: 12.1s
# 429:	learn: 0.3853774	total: 9.08s	remaining: 12s
# 430:	learn: 0.3847267	total: 9.1s	remaining: 12s
# 431:	learn: 0.3840277	total: 9.13s	remaining: 12s
# 432:	learn: 0.3837009	total: 9.15s	remaining: 12s
# 433:	learn: 0.3830517	total: 9.17s	remaining: 12s
# 434:	learn: 0.3823679	total: 9.19s	remaining: 11.9s
# 435:	learn: 0.3817163	total: 9.21s	remaining: 11.9s
# 436:	learn: 0.3806361	total: 9.23s	remaining: 11.9s
# 437:	learn: 0.3804179	total: 9.25s	remaining: 11.9s
# 438:	learn: 0.3798425	total: 9.27s	remaining: 11.8s
# 439:	learn: 0.3793398	total: 9.29s	remaining: 11.8s
# 440:	learn: 0.3789069	total: 9.31s	remaining: 11.8s
# 441:	learn: 0.3784190	total: 9.33s	remaining: 11.8s
# 442:	learn: 0.3777215	total: 9.36s	remaining: 11.8s
# 443:	learn: 0.3769596	total: 9.38s	remaining: 11.7s
# 444:	learn: 0.3765473	total: 9.4s	remaining: 11.7s
# 445:	learn: 0.3761118	total: 9.42s	remaining: 11.7s
# 446:	learn: 0.3757299	total: 9.44s	remaining: 11.7s
# 447:	learn: 0.3752368	total: 9.46s	remaining: 11.7s
# 448:	learn: 0.3747017	total: 9.48s	remaining: 11.6s
# 449:	learn: 0.3740743	total: 9.51s	remaining: 11.6s
# 450:	learn: 0.3736622	total: 9.53s	remaining: 11.6s
# 451:	learn: 0.3732233	total: 9.55s	remaining: 11.6s
# 452:	learn: 0.3726859	total: 9.57s	remaining: 11.6s
# 453:	learn: 0.3721620	total: 9.59s	remaining: 11.5s
# 454:	learn: 0.3717146	total: 9.62s	remaining: 11.5s
# 455:	learn: 0.3714460	total: 9.64s	remaining: 11.5s
# 456:	learn: 0.3708925	total: 9.66s	remaining: 11.5s
# 457:	learn: 0.3704987	total: 9.68s	remaining: 11.5s
# 458:	learn: 0.3701349	total: 9.7s	remaining: 11.4s
# 459:	learn: 0.3697313	total: 9.72s	remaining: 11.4s
# 460:	learn: 0.3692467	total: 9.74s	remaining: 11.4s
# 461:	learn: 0.3686463	total: 9.76s	remaining: 11.4s
# 462:	learn: 0.3680571	total: 9.78s	remaining: 11.3s
# 463:	learn: 0.3675659	total: 9.8s	remaining: 11.3s
# 464:	learn: 0.3673449	total: 9.82s	remaining: 11.3s
# 465:	learn: 0.3667063	total: 9.85s	remaining: 11.3s
# 466:	learn: 0.3664885	total: 9.87s	remaining: 11.3s
# 467:	learn: 0.3660654	total: 9.89s	remaining: 11.2s
# 468:	learn: 0.3658770	total: 9.91s	remaining: 11.2s
# 469:	learn: 0.3652952	total: 9.93s	remaining: 11.2s
# 470:	learn: 0.3647530	total: 9.95s	remaining: 11.2s
# 471:	learn: 0.3639982	total: 9.97s	remaining: 11.2s
# 472:	learn: 0.3636426	total: 9.99s	remaining: 11.1s
# 473:	learn: 0.3634152	total: 10s	remaining: 11.1s
# 474:	learn: 0.3628433	total: 10s	remaining: 11.1s
# 475:	learn: 0.3625320	total: 10.1s	remaining: 11.1s
# 476:	learn: 0.3621195	total: 10.1s	remaining: 11s
# 477:	learn: 0.3616289	total: 10.1s	remaining: 11s
# 478:	learn: 0.3610224	total: 10.1s	remaining: 11s
# 479:	learn: 0.3603320	total: 10.1s	remaining: 11s
# 480:	learn: 0.3600939	total: 10.2s	remaining: 11s
# 481:	learn: 0.3593523	total: 10.2s	remaining: 10.9s
# 482:	learn: 0.3587395	total: 10.2s	remaining: 10.9s
# 483:	learn: 0.3582082	total: 10.2s	remaining: 10.9s
# 484:	learn: 0.3576624	total: 10.2s	remaining: 10.9s
# 485:	learn: 0.3573340	total: 10.3s	remaining: 10.8s
# 486:	learn: 0.3568371	total: 10.3s	remaining: 10.8s
# 487:	learn: 0.3563793	total: 10.3s	remaining: 10.8s
# 488:	learn: 0.3559638	total: 10.3s	remaining: 10.8s
# 489:	learn: 0.3554890	total: 10.3s	remaining: 10.8s
# 490:	learn: 0.3551946	total: 10.4s	remaining: 10.7s
# 491:	learn: 0.3547785	total: 10.4s	remaining: 10.7s
# 492:	learn: 0.3540024	total: 10.4s	remaining: 10.7s
# 493:	learn: 0.3535718	total: 10.4s	remaining: 10.7s
# 494:	learn: 0.3531984	total: 10.4s	remaining: 10.7s
# 495:	learn: 0.3527658	total: 10.5s	remaining: 10.6s
# 496:	learn: 0.3525422	total: 10.5s	remaining: 10.6s
# 497:	learn: 0.3521228	total: 10.5s	remaining: 10.6s
# 498:	learn: 0.3514814	total: 10.5s	remaining: 10.6s
# 499:	learn: 0.3511542	total: 10.6s	remaining: 10.6s
# 500:	learn: 0.3505968	total: 10.6s	remaining: 10.5s
# 501:	learn: 0.3501497	total: 10.6s	remaining: 10.5s
# 502:	learn: 0.3497823	total: 10.6s	remaining: 10.5s
# 503:	learn: 0.3495686	total: 10.6s	remaining: 10.5s
# 504:	learn: 0.3492404	total: 10.7s	remaining: 10.4s
# 505:	learn: 0.3486959	total: 10.7s	remaining: 10.4s
# 506:	learn: 0.3482848	total: 10.7s	remaining: 10.4s
# 507:	learn: 0.3478732	total: 10.7s	remaining: 10.4s
# 508:	learn: 0.3474768	total: 10.7s	remaining: 10.4s
# 509:	learn: 0.3468815	total: 10.8s	remaining: 10.3s
# 510:	learn: 0.3463870	total: 10.8s	remaining: 10.3s
# 511:	learn: 0.3461151	total: 10.8s	remaining: 10.3s
# 512:	learn: 0.3456941	total: 10.8s	remaining: 10.3s
# 513:	learn: 0.3453717	total: 10.8s	remaining: 10.2s
# 514:	learn: 0.3448234	total: 10.9s	remaining: 10.2s
# 515:	learn: 0.3443476	total: 10.9s	remaining: 10.2s
# 516:	learn: 0.3437525	total: 10.9s	remaining: 10.2s
# 517:	learn: 0.3433732	total: 10.9s	remaining: 10.2s
# 518:	learn: 0.3428383	total: 10.9s	remaining: 10.1s
# 519:	learn: 0.3427122	total: 11s	remaining: 10.1s
# 520:	learn: 0.3422022	total: 11s	remaining: 10.1s
# 521:	learn: 0.3420003	total: 11s	remaining: 10.1s
# 522:	learn: 0.3415974	total: 11s	remaining: 10s
# 523:	learn: 0.3410285	total: 11s	remaining: 10s
# 524:	learn: 0.3404105	total: 11.1s	remaining: 10s
# 525:	learn: 0.3399517	total: 11.1s	remaining: 9.98s
# 526:	learn: 0.3396648	total: 11.1s	remaining: 9.96s
# 527:	learn: 0.3393930	total: 11.1s	remaining: 9.93s
# 528:	learn: 0.3390154	total: 11.1s	remaining: 9.91s
# 529:	learn: 0.3384591	total: 11.2s	remaining: 9.89s
# 530:	learn: 0.3381255	total: 11.2s	remaining: 9.87s
# 531:	learn: 0.3376101	total: 11.2s	remaining: 9.85s
# 532:	learn: 0.3372640	total: 11.2s	remaining: 9.82s
# 533:	learn: 0.3369023	total: 11.2s	remaining: 9.8s
# 534:	learn: 0.3365962	total: 11.3s	remaining: 9.78s
# 535:	learn: 0.3364486	total: 11.3s	remaining: 9.76s
# 536:	learn: 0.3360627	total: 11.3s	remaining: 9.74s
# 537:	learn: 0.3355708	total: 11.3s	remaining: 9.72s
# 538:	learn: 0.3350880	total: 11.3s	remaining: 9.7s
# 539:	learn: 0.3347426	total: 11.4s	remaining: 9.68s
# 540:	learn: 0.3344731	total: 11.4s	remaining: 9.66s
# 541:	learn: 0.3341612	total: 11.4s	remaining: 9.63s
# 542:	learn: 0.3336698	total: 11.4s	remaining: 9.61s
# 543:	learn: 0.3333144	total: 11.4s	remaining: 9.59s
# 544:	learn: 0.3328816	total: 11.5s	remaining: 9.57s
# 545:	learn: 0.3324945	total: 11.5s	remaining: 9.55s
# 546:	learn: 0.3319938	total: 11.5s	remaining: 9.53s
# 547:	learn: 0.3316817	total: 11.5s	remaining: 9.51s
# 548:	learn: 0.3312394	total: 11.5s	remaining: 9.48s
# 549:	learn: 0.3309654	total: 11.6s	remaining: 9.46s
# 550:	learn: 0.3305503	total: 11.6s	remaining: 9.44s
# 551:	learn: 0.3301619	total: 11.6s	remaining: 9.42s
# 552:	learn: 0.3299436	total: 11.6s	remaining: 9.4s
# 553:	learn: 0.3294227	total: 11.7s	remaining: 9.38s
# 554:	learn: 0.3289342	total: 11.7s	remaining: 9.36s
# 555:	learn: 0.3284077	total: 11.7s	remaining: 9.34s
# 556:	learn: 0.3279608	total: 11.7s	remaining: 9.32s
# 557:	learn: 0.3276262	total: 11.7s	remaining: 9.29s
# 558:	learn: 0.3272235	total: 11.8s	remaining: 9.27s
# 559:	learn: 0.3267368	total: 11.8s	remaining: 9.25s
# 560:	learn: 0.3262161	total: 11.8s	remaining: 9.23s
# 561:	learn: 0.3257825	total: 11.8s	remaining: 9.21s
# 562:	learn: 0.3254545	total: 11.8s	remaining: 9.19s
# 563:	learn: 0.3250516	total: 11.9s	remaining: 9.17s
# 564:	learn: 0.3245647	total: 11.9s	remaining: 9.15s
# 565:	learn: 0.3240389	total: 11.9s	remaining: 9.13s
# 566:	learn: 0.3235197	total: 11.9s	remaining: 9.11s
# 567:	learn: 0.3231159	total: 11.9s	remaining: 9.09s
# 568:	learn: 0.3223068	total: 12s	remaining: 9.07s
# 569:	learn: 0.3218801	total: 12s	remaining: 9.05s
# 570:	learn: 0.3214925	total: 12s	remaining: 9.04s
# 571:	learn: 0.3209279	total: 12.1s	remaining: 9.02s
# 572:	learn: 0.3206265	total: 12.1s	remaining: 9s
# 573:	learn: 0.3201617	total: 12.1s	remaining: 8.98s
# 574:	learn: 0.3197364	total: 12.1s	remaining: 8.96s
# 575:	learn: 0.3195002	total: 12.1s	remaining: 8.94s
# 576:	learn: 0.3188117	total: 12.2s	remaining: 8.91s
# 577:	learn: 0.3183786	total: 12.2s	remaining: 8.89s
# 578:	learn: 0.3178088	total: 12.2s	remaining: 8.87s
# 579:	learn: 0.3172438	total: 12.2s	remaining: 8.85s
# 580:	learn: 0.3165962	total: 12.2s	remaining: 8.83s
# 581:	learn: 0.3162033	total: 12.3s	remaining: 8.81s
# 582:	learn: 0.3159658	total: 12.3s	remaining: 8.79s
# 583:	learn: 0.3157482	total: 12.3s	remaining: 8.77s
# 584:	learn: 0.3155274	total: 12.3s	remaining: 8.75s
# 585:	learn: 0.3153553	total: 12.3s	remaining: 8.72s
# 586:	learn: 0.3149615	total: 12.4s	remaining: 8.7s
# 587:	learn: 0.3147215	total: 12.4s	remaining: 8.68s
# 588:	learn: 0.3143682	total: 12.4s	remaining: 8.66s
# 589:	learn: 0.3141595	total: 12.4s	remaining: 8.64s
# 590:	learn: 0.3135244	total: 12.5s	remaining: 8.62s
# 591:	learn: 0.3131474	total: 12.5s	remaining: 8.6s
# 592:	learn: 0.3129669	total: 12.5s	remaining: 8.57s
# 593:	learn: 0.3123780	total: 12.5s	remaining: 8.55s
# 594:	learn: 0.3118116	total: 12.5s	remaining: 8.53s
# 595:	learn: 0.3115607	total: 12.6s	remaining: 8.51s
# 596:	learn: 0.3111609	total: 12.6s	remaining: 8.49s
# 597:	learn: 0.3108812	total: 12.6s	remaining: 8.47s
# 598:	learn: 0.3105792	total: 12.6s	remaining: 8.45s
# 599:	learn: 0.3102145	total: 12.6s	remaining: 8.43s
# 600:	learn: 0.3099078	total: 12.7s	remaining: 8.4s
# 601:	learn: 0.3092722	total: 12.7s	remaining: 8.38s
# 602:	learn: 0.3087340	total: 12.7s	remaining: 8.36s
# 603:	learn: 0.3084896	total: 12.7s	remaining: 8.34s
# 604:	learn: 0.3080737	total: 12.7s	remaining: 8.32s
# 605:	learn: 0.3077677	total: 12.8s	remaining: 8.3s
# 606:	learn: 0.3073593	total: 12.8s	remaining: 8.28s
# 607:	learn: 0.3069272	total: 12.8s	remaining: 8.26s
# 608:	learn: 0.3064518	total: 12.8s	remaining: 8.24s
# 609:	learn: 0.3060106	total: 12.8s	remaining: 8.21s
# 610:	learn: 0.3055524	total: 12.9s	remaining: 8.19s
# 611:	learn: 0.3049326	total: 12.9s	remaining: 8.17s
# 612:	learn: 0.3046987	total: 12.9s	remaining: 8.15s
# 613:	learn: 0.3042501	total: 12.9s	remaining: 8.13s
# 614:	learn: 0.3037860	total: 13s	remaining: 8.11s
# 615:	learn: 0.3031637	total: 13s	remaining: 8.09s
# 616:	learn: 0.3028801	total: 13s	remaining: 8.07s
# 617:	learn: 0.3021971	total: 13s	remaining: 8.05s
# 618:	learn: 0.3018722	total: 13s	remaining: 8.03s
# 619:	learn: 0.3014757	total: 13.1s	remaining: 8.01s
# 620:	learn: 0.3009540	total: 13.1s	remaining: 7.99s
# 621:	learn: 0.3005902	total: 13.1s	remaining: 7.97s
# 622:	learn: 0.3003856	total: 13.1s	remaining: 7.95s
# 623:	learn: 0.2999457	total: 13.2s	remaining: 7.92s
# 624:	learn: 0.2996822	total: 13.2s	remaining: 7.9s
# 625:	learn: 0.2992001	total: 13.2s	remaining: 7.88s
# 626:	learn: 0.2990677	total: 13.2s	remaining: 7.86s
# 627:	learn: 0.2986389	total: 13.2s	remaining: 7.84s
# 628:	learn: 0.2979537	total: 13.3s	remaining: 7.82s
# 629:	learn: 0.2975764	total: 13.3s	remaining: 7.8s
# 630:	learn: 0.2971190	total: 13.3s	remaining: 7.78s
# 631:	learn: 0.2966685	total: 13.3s	remaining: 7.76s
# 632:	learn: 0.2958336	total: 13.3s	remaining: 7.74s
# 633:	learn: 0.2954133	total: 13.4s	remaining: 7.72s
# 634:	learn: 0.2952128	total: 13.4s	remaining: 7.7s
# 635:	learn: 0.2947120	total: 13.4s	remaining: 7.68s
# 636:	learn: 0.2943590	total: 13.4s	remaining: 7.66s
# 637:	learn: 0.2938862	total: 13.5s	remaining: 7.63s
# 638:	learn: 0.2936299	total: 13.5s	remaining: 7.61s
# 639:	learn: 0.2934131	total: 13.5s	remaining: 7.59s
# 640:	learn: 0.2928840	total: 13.5s	remaining: 7.57s
# 641:	learn: 0.2923140	total: 13.5s	remaining: 7.55s
# 642:	learn: 0.2920678	total: 13.6s	remaining: 7.53s
# 643:	learn: 0.2918920	total: 13.6s	remaining: 7.5s
# 644:	learn: 0.2913573	total: 13.6s	remaining: 7.48s
# 645:	learn: 0.2910808	total: 13.6s	remaining: 7.46s
# 646:	learn: 0.2907362	total: 13.6s	remaining: 7.44s
# 647:	learn: 0.2905180	total: 13.7s	remaining: 7.42s
# 648:	learn: 0.2900905	total: 13.7s	remaining: 7.4s
# 649:	learn: 0.2898324	total: 13.7s	remaining: 7.38s
# 650:	learn: 0.2895473	total: 13.7s	remaining: 7.36s
# 651:	learn: 0.2892646	total: 13.7s	remaining: 7.33s
# 652:	learn: 0.2888645	total: 13.8s	remaining: 7.31s
# 653:	learn: 0.2886564	total: 13.8s	remaining: 7.29s
# 654:	learn: 0.2882214	total: 13.8s	remaining: 7.27s
# 655:	learn: 0.2879740	total: 13.8s	remaining: 7.25s
# 656:	learn: 0.2876300	total: 13.8s	remaining: 7.23s
# 657:	learn: 0.2873027	total: 13.9s	remaining: 7.21s
# 658:	learn: 0.2871003	total: 13.9s	remaining: 7.18s
# 659:	learn: 0.2867570	total: 13.9s	remaining: 7.17s
# 660:	learn: 0.2864626	total: 13.9s	remaining: 7.14s
# 661:	learn: 0.2860175	total: 13.9s	remaining: 7.12s
# 662:	learn: 0.2854339	total: 14s	remaining: 7.1s
# 663:	learn: 0.2851891	total: 14s	remaining: 7.08s
# 664:	learn: 0.2845482	total: 14s	remaining: 7.06s
# 665:	learn: 0.2840586	total: 14s	remaining: 7.04s
# 666:	learn: 0.2836283	total: 14.1s	remaining: 7.02s
# 667:	learn: 0.2832875	total: 14.1s	remaining: 7s
# 668:	learn: 0.2828431	total: 14.1s	remaining: 6.98s
# 669:	learn: 0.2824250	total: 14.1s	remaining: 6.96s
# 670:	learn: 0.2819138	total: 14.1s	remaining: 6.93s
# 671:	learn: 0.2816205	total: 14.2s	remaining: 6.91s
# 672:	learn: 0.2813297	total: 14.2s	remaining: 6.89s
# 673:	learn: 0.2807758	total: 14.2s	remaining: 6.87s
# 674:	learn: 0.2803070	total: 14.2s	remaining: 6.85s
# 675:	learn: 0.2799902	total: 14.2s	remaining: 6.83s
# 676:	learn: 0.2796086	total: 14.3s	remaining: 6.81s
# 677:	learn: 0.2792962	total: 14.3s	remaining: 6.79s
# 678:	learn: 0.2786523	total: 14.3s	remaining: 6.77s
# 679:	learn: 0.2783480	total: 14.3s	remaining: 6.75s
# 680:	learn: 0.2781875	total: 14.4s	remaining: 6.72s
# 681:	learn: 0.2780227	total: 14.4s	remaining: 6.7s
# 682:	learn: 0.2777353	total: 14.4s	remaining: 6.68s
# 683:	learn: 0.2772445	total: 14.4s	remaining: 6.66s
# 684:	learn: 0.2768470	total: 14.4s	remaining: 6.64s
# 685:	learn: 0.2764854	total: 14.5s	remaining: 6.62s
# 686:	learn: 0.2762424	total: 14.5s	remaining: 6.59s
# 687:	learn: 0.2758968	total: 14.5s	remaining: 6.57s
# 688:	learn: 0.2757780	total: 14.5s	remaining: 6.55s
# 689:	learn: 0.2753558	total: 14.5s	remaining: 6.53s
# 690:	learn: 0.2752070	total: 14.6s	remaining: 6.51s
# 691:	learn: 0.2749835	total: 14.6s	remaining: 6.49s
# 692:	learn: 0.2745160	total: 14.6s	remaining: 6.47s
# 693:	learn: 0.2743077	total: 14.6s	remaining: 6.45s
# 694:	learn: 0.2738855	total: 14.6s	remaining: 6.43s
# 695:	learn: 0.2734277	total: 14.7s	remaining: 6.41s
# 696:	learn: 0.2730860	total: 14.7s	remaining: 6.38s
# 697:	learn: 0.2727470	total: 14.7s	remaining: 6.36s
# 698:	learn: 0.2725299	total: 14.7s	remaining: 6.34s
# 699:	learn: 0.2722223	total: 14.7s	remaining: 6.32s
# 700:	learn: 0.2720209	total: 14.8s	remaining: 6.3s
# 701:	learn: 0.2716531	total: 14.8s	remaining: 6.28s
# 702:	learn: 0.2712111	total: 14.8s	remaining: 6.26s
# 703:	learn: 0.2709969	total: 14.8s	remaining: 6.24s
# 704:	learn: 0.2707060	total: 14.9s	remaining: 6.21s
# 705:	learn: 0.2703958	total: 14.9s	remaining: 6.19s
# 706:	learn: 0.2700748	total: 14.9s	remaining: 6.17s
# 707:	learn: 0.2697793	total: 14.9s	remaining: 6.15s
# 708:	learn: 0.2695930	total: 14.9s	remaining: 6.13s
# 709:	learn: 0.2693274	total: 15s	remaining: 6.11s
# 710:	learn: 0.2691685	total: 15s	remaining: 6.09s
# 711:	learn: 0.2687162	total: 15s	remaining: 6.07s
# 712:	learn: 0.2684900	total: 15s	remaining: 6.04s
# 713:	learn: 0.2680636	total: 15s	remaining: 6.02s
# 714:	learn: 0.2675768	total: 15.1s	remaining: 6s
# 715:	learn: 0.2671933	total: 15.1s	remaining: 5.98s
# 716:	learn: 0.2666740	total: 15.1s	remaining: 5.96s
# 717:	learn: 0.2662158	total: 15.1s	remaining: 5.94s
# 718:	learn: 0.2656841	total: 15.2s	remaining: 5.92s
# 719:	learn: 0.2653871	total: 15.2s	remaining: 5.9s
# 720:	learn: 0.2649226	total: 15.2s	remaining: 5.88s
# 721:	learn: 0.2645229	total: 15.2s	remaining: 5.86s
# 722:	learn: 0.2643832	total: 15.2s	remaining: 5.84s
# 723:	learn: 0.2641289	total: 15.3s	remaining: 5.82s
# 724:	learn: 0.2638275	total: 15.3s	remaining: 5.79s
# 725:	learn: 0.2634461	total: 15.3s	remaining: 5.77s
# 726:	learn: 0.2632333	total: 15.3s	remaining: 5.75s
# 727:	learn: 0.2629011	total: 15.3s	remaining: 5.73s
# 728:	learn: 0.2626421	total: 15.4s	remaining: 5.71s
# 729:	learn: 0.2622907	total: 15.4s	remaining: 5.69s
# 730:	learn: 0.2619262	total: 15.4s	remaining: 5.67s
# 731:	learn: 0.2616475	total: 15.4s	remaining: 5.65s
# 732:	learn: 0.2613876	total: 15.4s	remaining: 5.63s
# 733:	learn: 0.2610559	total: 15.5s	remaining: 5.6s
# 734:	learn: 0.2608989	total: 15.5s	remaining: 5.58s
# 735:	learn: 0.2607476	total: 15.5s	remaining: 5.56s
# 736:	learn: 0.2602547	total: 15.5s	remaining: 5.54s
# 737:	learn: 0.2597809	total: 15.5s	remaining: 5.52s
# 738:	learn: 0.2595062	total: 15.6s	remaining: 5.5s
# 739:	learn: 0.2590977	total: 15.6s	remaining: 5.48s
# 740:	learn: 0.2588572	total: 15.6s	remaining: 5.46s
# 741:	learn: 0.2585957	total: 15.6s	remaining: 5.43s
# 742:	learn: 0.2580913	total: 15.7s	remaining: 5.41s
# 743:	learn: 0.2577565	total: 15.7s	remaining: 5.39s
# 744:	learn: 0.2574987	total: 15.7s	remaining: 5.37s
# 745:	learn: 0.2571861	total: 15.7s	remaining: 5.35s
# 746:	learn: 0.2569610	total: 15.7s	remaining: 5.33s
# 747:	learn: 0.2565154	total: 15.8s	remaining: 5.31s
# 748:	learn: 0.2563519	total: 15.8s	remaining: 5.29s
# 749:	learn: 0.2560224	total: 15.8s	remaining: 5.27s
# 750:	learn: 0.2558580	total: 15.8s	remaining: 5.25s
# 751:	learn: 0.2557061	total: 15.8s	remaining: 5.22s
# 752:	learn: 0.2553948	total: 15.9s	remaining: 5.2s
# 753:	learn: 0.2552214	total: 15.9s	remaining: 5.18s
# 754:	learn: 0.2551349	total: 15.9s	remaining: 5.16s
# 755:	learn: 0.2547533	total: 15.9s	remaining: 5.14s
# 756:	learn: 0.2545118	total: 15.9s	remaining: 5.12s
# 757:	learn: 0.2538712	total: 16s	remaining: 5.1s
# 758:	learn: 0.2535732	total: 16s	remaining: 5.08s
# 759:	learn: 0.2530995	total: 16s	remaining: 5.05s
# 760:	learn: 0.2528297	total: 16s	remaining: 5.03s
# 761:	learn: 0.2526854	total: 16.1s	remaining: 5.01s
# 762:	learn: 0.2524436	total: 16.1s	remaining: 4.99s
# 763:	learn: 0.2522615	total: 16.1s	remaining: 4.97s
# 764:	learn: 0.2520933	total: 16.1s	remaining: 4.95s
# 765:	learn: 0.2518363	total: 16.1s	remaining: 4.93s
# 766:	learn: 0.2514071	total: 16.2s	remaining: 4.91s
# 767:	learn: 0.2511566	total: 16.2s	remaining: 4.89s
# 768:	learn: 0.2507873	total: 16.2s	remaining: 4.87s
# 769:	learn: 0.2504419	total: 16.2s	remaining: 4.84s
# 770:	learn: 0.2501987	total: 16.2s	remaining: 4.82s
# 771:	learn: 0.2499998	total: 16.3s	remaining: 4.8s
# 772:	learn: 0.2497137	total: 16.3s	remaining: 4.78s
# 773:	learn: 0.2494327	total: 16.3s	remaining: 4.76s
# 774:	learn: 0.2491705	total: 16.3s	remaining: 4.74s
# 775:	learn: 0.2489406	total: 16.3s	remaining: 4.72s
# 776:	learn: 0.2486654	total: 16.4s	remaining: 4.7s
# 777:	learn: 0.2482776	total: 16.4s	remaining: 4.67s
# 778:	learn: 0.2478787	total: 16.4s	remaining: 4.65s
# 779:	learn: 0.2475453	total: 16.4s	remaining: 4.63s
# 780:	learn: 0.2472277	total: 16.4s	remaining: 4.61s
# 781:	learn: 0.2469658	total: 16.5s	remaining: 4.59s
# 782:	learn: 0.2466182	total: 16.5s	remaining: 4.57s
# 783:	learn: 0.2464073	total: 16.5s	remaining: 4.55s
# 784:	learn: 0.2460340	total: 16.5s	remaining: 4.53s
# 785:	learn: 0.2454274	total: 16.6s	remaining: 4.51s
# 786:	learn: 0.2451559	total: 16.6s	remaining: 4.49s
# 787:	learn: 0.2448174	total: 16.6s	remaining: 4.46s
# 788:	learn: 0.2446157	total: 16.6s	remaining: 4.44s
# 789:	learn: 0.2443963	total: 16.6s	remaining: 4.42s
# 790:	learn: 0.2441691	total: 16.7s	remaining: 4.4s
# 791:	learn: 0.2439256	total: 16.7s	remaining: 4.38s
# 792:	learn: 0.2435960	total: 16.7s	remaining: 4.36s
# 793:	learn: 0.2432215	total: 16.7s	remaining: 4.34s
# 794:	learn: 0.2427829	total: 16.7s	remaining: 4.32s
# 795:	learn: 0.2425795	total: 16.8s	remaining: 4.3s
# 796:	learn: 0.2421979	total: 16.8s	remaining: 4.28s
# 797:	learn: 0.2419646	total: 16.8s	remaining: 4.25s
# 798:	learn: 0.2417209	total: 16.8s	remaining: 4.23s
# 799:	learn: 0.2413958	total: 16.9s	remaining: 4.21s
# 800:	learn: 0.2410259	total: 16.9s	remaining: 4.19s
# 801:	learn: 0.2407564	total: 16.9s	remaining: 4.17s
# 802:	learn: 0.2403466	total: 16.9s	remaining: 4.15s
# 803:	learn: 0.2400040	total: 16.9s	remaining: 4.13s
# 804:	learn: 0.2397439	total: 17s	remaining: 4.11s
# 805:	learn: 0.2394673	total: 17s	remaining: 4.09s
# 806:	learn: 0.2392022	total: 17s	remaining: 4.07s
# 807:	learn: 0.2387639	total: 17s	remaining: 4.04s
# 808:	learn: 0.2386435	total: 17s	remaining: 4.02s
# 809:	learn: 0.2383561	total: 17.1s	remaining: 4s
# 810:	learn: 0.2380401	total: 17.1s	remaining: 3.98s
# 811:	learn: 0.2378439	total: 17.1s	remaining: 3.96s
# 812:	learn: 0.2375684	total: 17.1s	remaining: 3.94s
# 813:	learn: 0.2373155	total: 17.1s	remaining: 3.92s
# 814:	learn: 0.2371413	total: 17.2s	remaining: 3.9s
# 815:	learn: 0.2367968	total: 17.2s	remaining: 3.88s
# 816:	learn: 0.2365397	total: 17.2s	remaining: 3.85s
# 817:	learn: 0.2363238	total: 17.2s	remaining: 3.83s
# 818:	learn: 0.2361967	total: 17.3s	remaining: 3.81s
# 819:	learn: 0.2360025	total: 17.3s	remaining: 3.79s
# 820:	learn: 0.2359080	total: 17.3s	remaining: 3.77s
# 821:	learn: 0.2358251	total: 17.3s	remaining: 3.75s
# 822:	learn: 0.2353054	total: 17.3s	remaining: 3.73s
# 823:	learn: 0.2350740	total: 17.4s	remaining: 3.71s
# 824:	learn: 0.2346247	total: 17.4s	remaining: 3.69s
# 825:	learn: 0.2343227	total: 17.4s	remaining: 3.67s
# 826:	learn: 0.2341333	total: 17.4s	remaining: 3.64s
# 827:	learn: 0.2339046	total: 17.4s	remaining: 3.62s
# 828:	learn: 0.2337734	total: 17.5s	remaining: 3.6s
# 829:	learn: 0.2336157	total: 17.5s	remaining: 3.58s
# 830:	learn: 0.2334447	total: 17.5s	remaining: 3.56s
# 831:	learn: 0.2332486	total: 17.5s	remaining: 3.54s
# 832:	learn: 0.2329613	total: 17.5s	remaining: 3.52s
# 833:	learn: 0.2326693	total: 17.6s	remaining: 3.5s
# 834:	learn: 0.2324598	total: 17.6s	remaining: 3.47s
# 835:	learn: 0.2320302	total: 17.6s	remaining: 3.45s
# 836:	learn: 0.2318297	total: 17.6s	remaining: 3.43s
# 837:	learn: 0.2315837	total: 17.6s	remaining: 3.41s
# 838:	learn: 0.2313830	total: 17.7s	remaining: 3.39s
# 839:	learn: 0.2311143	total: 17.7s	remaining: 3.37s
# 840:	learn: 0.2307071	total: 17.7s	remaining: 3.35s
# 841:	learn: 0.2305551	total: 17.7s	remaining: 3.33s
# 842:	learn: 0.2303407	total: 17.7s	remaining: 3.31s
# 843:	learn: 0.2300063	total: 17.8s	remaining: 3.28s
# 844:	learn: 0.2296740	total: 17.8s	remaining: 3.26s
# 845:	learn: 0.2292831	total: 17.8s	remaining: 3.24s
# 846:	learn: 0.2289205	total: 17.8s	remaining: 3.22s
# 847:	learn: 0.2287429	total: 17.9s	remaining: 3.2s
# 848:	learn: 0.2284845	total: 17.9s	remaining: 3.18s
# 849:	learn: 0.2282272	total: 17.9s	remaining: 3.16s
# 850:	learn: 0.2278051	total: 17.9s	remaining: 3.14s
# 851:	learn: 0.2275847	total: 17.9s	remaining: 3.12s
# 852:	learn: 0.2273938	total: 18s	remaining: 3.1s
# 853:	learn: 0.2271401	total: 18s	remaining: 3.07s
# 854:	learn: 0.2268631	total: 18s	remaining: 3.05s
# 855:	learn: 0.2266066	total: 18s	remaining: 3.03s
# 856:	learn: 0.2263475	total: 18s	remaining: 3.01s
# 857:	learn: 0.2261129	total: 18.1s	remaining: 2.99s
# 858:	learn: 0.2258751	total: 18.1s	remaining: 2.97s
# 859:	learn: 0.2254514	total: 18.1s	remaining: 2.95s
# 860:	learn: 0.2252931	total: 18.1s	remaining: 2.93s
# 861:	learn: 0.2249707	total: 18.2s	remaining: 2.9s
# 862:	learn: 0.2246698	total: 18.2s	remaining: 2.88s
# 863:	learn: 0.2244184	total: 18.2s	remaining: 2.86s
# 864:	learn: 0.2242043	total: 18.2s	remaining: 2.84s
# 865:	learn: 0.2240139	total: 18.2s	remaining: 2.82s
# 866:	learn: 0.2235955	total: 18.3s	remaining: 2.8s
# 867:	learn: 0.2233376	total: 18.3s	remaining: 2.78s
# 868:	learn: 0.2229472	total: 18.3s	remaining: 2.76s
# 869:	learn: 0.2227467	total: 18.3s	remaining: 2.74s
# 870:	learn: 0.2224753	total: 18.3s	remaining: 2.72s
# 871:	learn: 0.2221788	total: 18.4s	remaining: 2.69s
# 872:	learn: 0.2219210	total: 18.4s	remaining: 2.67s
# 873:	learn: 0.2214405	total: 18.4s	remaining: 2.65s
# 874:	learn: 0.2211945	total: 18.4s	remaining: 2.63s
# 875:	learn: 0.2207656	total: 18.4s	remaining: 2.61s
# 876:	learn: 0.2204951	total: 18.5s	remaining: 2.59s
# 877:	learn: 0.2202023	total: 18.5s	remaining: 2.57s
# 878:	learn: 0.2200888	total: 18.5s	remaining: 2.55s
# 879:	learn: 0.2198836	total: 18.5s	remaining: 2.53s
# 880:	learn: 0.2194092	total: 18.6s	remaining: 2.51s
# 881:	learn: 0.2192074	total: 18.6s	remaining: 2.48s
# 882:	learn: 0.2189985	total: 18.6s	remaining: 2.46s
# 883:	learn: 0.2186657	total: 18.6s	remaining: 2.44s
# 884:	learn: 0.2182563	total: 18.6s	remaining: 2.42s
# 885:	learn: 0.2179533	total: 18.7s	remaining: 2.4s
# 886:	learn: 0.2178367	total: 18.7s	remaining: 2.38s
# 887:	learn: 0.2176833	total: 18.7s	remaining: 2.36s
# 888:	learn: 0.2174432	total: 18.7s	remaining: 2.34s
# 889:	learn: 0.2171179	total: 18.7s	remaining: 2.32s
# 890:	learn: 0.2168135	total: 18.8s	remaining: 2.3s
# 891:	learn: 0.2166505	total: 18.8s	remaining: 2.27s
# 892:	learn: 0.2164862	total: 18.8s	remaining: 2.25s
# 893:	learn: 0.2163052	total: 18.8s	remaining: 2.23s
# 894:	learn: 0.2161710	total: 18.9s	remaining: 2.21s
# 895:	learn: 0.2159034	total: 18.9s	remaining: 2.19s
# 896:	learn: 0.2154239	total: 18.9s	remaining: 2.17s
# 897:	learn: 0.2152468	total: 18.9s	remaining: 2.15s
# 898:	learn: 0.2151282	total: 18.9s	remaining: 2.13s
# 899:	learn: 0.2149798	total: 19s	remaining: 2.1s
# 900:	learn: 0.2146904	total: 19s	remaining: 2.08s
# 901:	learn: 0.2143041	total: 19s	remaining: 2.06s
# 902:	learn: 0.2140252	total: 19s	remaining: 2.04s
# 903:	learn: 0.2135726	total: 19s	remaining: 2.02s
# 904:	learn: 0.2133483	total: 19.1s	remaining: 2s
# 905:	learn: 0.2131695	total: 19.1s	remaining: 1.98s
# 906:	learn: 0.2127456	total: 19.1s	remaining: 1.96s
# 907:	learn: 0.2123862	total: 19.1s	remaining: 1.94s
# 908:	learn: 0.2122463	total: 19.1s	remaining: 1.92s
# 909:	learn: 0.2120046	total: 19.2s	remaining: 1.9s
# 910:	learn: 0.2115954	total: 19.2s	remaining: 1.88s
# 911:	learn: 0.2113372	total: 19.2s	remaining: 1.85s
# 912:	learn: 0.2112094	total: 19.2s	remaining: 1.83s
# 913:	learn: 0.2110277	total: 19.3s	remaining: 1.81s
# 914:	learn: 0.2106681	total: 19.3s	remaining: 1.79s
# 915:	learn: 0.2104443	total: 19.3s	remaining: 1.77s
# 916:	learn: 0.2101713	total: 19.3s	remaining: 1.75s
# 917:	learn: 0.2098405	total: 19.3s	remaining: 1.73s
# 918:	learn: 0.2096382	total: 19.4s	remaining: 1.71s
# 919:	learn: 0.2095876	total: 19.4s	remaining: 1.69s
# 920:	learn: 0.2093647	total: 19.4s	remaining: 1.66s
# 921:	learn: 0.2090005	total: 19.4s	remaining: 1.64s
# 922:	learn: 0.2088940	total: 19.4s	remaining: 1.62s
# 923:	learn: 0.2087138	total: 19.5s	remaining: 1.6s
# 924:	learn: 0.2083974	total: 19.5s	remaining: 1.58s
# 925:	learn: 0.2081419	total: 19.5s	remaining: 1.56s
# 926:	learn: 0.2079170	total: 19.5s	remaining: 1.54s
# 927:	learn: 0.2078131	total: 19.5s	remaining: 1.52s
# 928:	learn: 0.2076317	total: 19.6s	remaining: 1.49s
# 929:	learn: 0.2074409	total: 19.6s	remaining: 1.47s
# 930:	learn: 0.2071945	total: 19.6s	remaining: 1.45s
# 931:	learn: 0.2068596	total: 19.6s	remaining: 1.43s
# 932:	learn: 0.2066733	total: 19.6s	remaining: 1.41s
# 933:	learn: 0.2064808	total: 19.7s	remaining: 1.39s
# 934:	learn: 0.2061549	total: 19.7s	remaining: 1.37s
# 935:	learn: 0.2058362	total: 19.7s	remaining: 1.35s
# 936:	learn: 0.2056054	total: 19.7s	remaining: 1.33s
# 937:	learn: 0.2052912	total: 19.8s	remaining: 1.3s
# 938:	learn: 0.2051341	total: 19.8s	remaining: 1.28s
# 939:	learn: 0.2048386	total: 19.8s	remaining: 1.26s
# 940:	learn: 0.2047008	total: 19.8s	remaining: 1.24s
# 941:	learn: 0.2045441	total: 19.8s	remaining: 1.22s
# 942:	learn: 0.2043020	total: 19.9s	remaining: 1.2s
# 943:	learn: 0.2041439	total: 19.9s	remaining: 1.18s
# 944:	learn: 0.2039447	total: 19.9s	remaining: 1.16s
# 945:	learn: 0.2037020	total: 19.9s	remaining: 1.14s
# 946:	learn: 0.2034841	total: 19.9s	remaining: 1.11s
# 947:	learn: 0.2032389	total: 20s	remaining: 1.09s
# 948:	learn: 0.2030736	total: 20s	remaining: 1.07s
# 949:	learn: 0.2029518	total: 20s	remaining: 1.05s
# 950:	learn: 0.2026688	total: 20s	remaining: 1.03s
# 951:	learn: 0.2025205	total: 20s	remaining: 1.01s
# 952:	learn: 0.2022871	total: 20.1s	remaining: 990ms
# 953:	learn: 0.2020416	total: 20.1s	remaining: 969ms
# 954:	learn: 0.2018888	total: 20.1s	remaining: 948ms
# 955:	learn: 0.2016060	total: 20.1s	remaining: 927ms
# 956:	learn: 0.2013478	total: 20.2s	remaining: 905ms
# 957:	learn: 0.2010444	total: 20.2s	remaining: 884ms
# 958:	learn: 0.2008053	total: 20.2s	remaining: 863ms
# 959:	learn: 0.2006501	total: 20.2s	remaining: 842ms
# 960:	learn: 0.2004015	total: 20.2s	remaining: 821ms
# 961:	learn: 0.2002312	total: 20.3s	remaining: 800ms
# 962:	learn: 0.2000748	total: 20.3s	remaining: 779ms
# 963:	learn: 0.1996297	total: 20.3s	remaining: 758ms
# 964:	learn: 0.1993259	total: 20.3s	remaining: 737ms
# 965:	learn: 0.1991299	total: 20.3s	remaining: 716ms
# 966:	learn: 0.1989011	total: 20.4s	remaining: 695ms
# 967:	learn: 0.1986443	total: 20.4s	remaining: 674ms
# 968:	learn: 0.1983895	total: 20.4s	remaining: 653ms
# 969:	learn: 0.1982633	total: 20.4s	remaining: 632ms
# 970:	learn: 0.1980756	total: 20.4s	remaining: 611ms
# 971:	learn: 0.1979617	total: 20.5s	remaining: 590ms
# 972:	learn: 0.1977382	total: 20.5s	remaining: 569ms
# 973:	learn: 0.1974945	total: 20.5s	remaining: 548ms
# 974:	learn: 0.1972542	total: 20.5s	remaining: 527ms
# 975:	learn: 0.1969602	total: 20.6s	remaining: 505ms
# 976:	learn: 0.1968166	total: 20.6s	remaining: 484ms
# 977:	learn: 0.1966107	total: 20.6s	remaining: 463ms
# 978:	learn: 0.1963688	total: 20.6s	remaining: 442ms
# 979:	learn: 0.1961381	total: 20.6s	remaining: 421ms
# 980:	learn: 0.1958249	total: 20.7s	remaining: 400ms
# 981:	learn: 0.1955899	total: 20.7s	remaining: 379ms
# 982:	learn: 0.1954253	total: 20.7s	remaining: 358ms
# 983:	learn: 0.1952035	total: 20.7s	remaining: 337ms
# 984:	learn: 0.1950504	total: 20.7s	remaining: 316ms
# 985:	learn: 0.1948920	total: 20.8s	remaining: 295ms
# 986:	learn: 0.1946993	total: 20.8s	remaining: 274ms
# 987:	learn: 0.1945091	total: 20.8s	remaining: 253ms
# 988:	learn: 0.1943798	total: 20.8s	remaining: 232ms
# 989:	learn: 0.1940794	total: 20.8s	remaining: 211ms
# 990:	learn: 0.1938522	total: 20.9s	remaining: 190ms
# 991:	learn: 0.1936071	total: 20.9s	remaining: 168ms
# 992:	learn: 0.1934340	total: 20.9s	remaining: 147ms
# 993:	learn: 0.1932877	total: 20.9s	remaining: 126ms
# 994:	learn: 0.1931067	total: 20.9s	remaining: 105ms
# 995:	learn: 0.1928500	total: 21s	remaining: 84.2ms
# 996:	learn: 0.1926803	total: 21s	remaining: 63.2ms
# 997:	learn: 0.1925113	total: 21s	remaining: 42.1ms
# 998:	learn: 0.1922256	total: 21s	remaining: 21.1ms
# 999:	learn: 0.1920431	total: 21.1s	remaining: 0us
# CPU times: total: 48 s
# Wall time: 26.9 s

# %%
# %time
accuracy_score(cbc.predict(test_X),test_df[target_column])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 0.7642847929833613

# %%
print(classification_report(train_df[target_column],cbc.predict(train_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4364
#            1       0.97      0.98      0.97      3674
#            2       0.99      0.96      0.97      4785
#            3       0.97      0.95      0.96      2209
#            4       0.98      0.97      0.98      2839
#            5       0.98      0.99      0.98      9798
#            6       0.98      0.97      0.97      3810
#
#     accuracy                           0.98     31479
#    macro avg       0.98      0.97      0.97     31479
# weighted avg       0.98      0.98      0.98     31479

# %%
print(classification_report(test_df[target_column],cbc.predict(test_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78      2150
#            1       0.79      0.76      0.77      1809
#            2       0.77      0.70      0.73      2357
#            3       0.70      0.63      0.67      1088
#            4       0.74      0.72      0.73      1398
#            5       0.79      0.84      0.81      4827
#            6       0.72      0.72      0.72      1877
#
#     accuracy                           0.76     15506
#    macro avg       0.75      0.74      0.75     15506
# weighted avg       0.76      0.76      0.76     15506

# %% [markdown]
# ## Support Vector Machine

# %%
svc.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 42,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
# %%time
svc.fit(train_X,train_df[target_column])
# Out:
# CPU times: total: 2min 34s
# Wall time: 2min 34s
# SVC(random_state=42)

# %%
# %%time
print(accuracy_score(svc.predict(test_X),test_df[target_column]))
# Out:
# 0.7691216303366438
# CPU times: total: 2min 3s
# Wall time: 2min 3s

# %%
print(classification_report(train_df[target_column],svc.predict(train_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.81      4364
#            1       0.81      0.80      0.81      3674
#            2       0.81      0.75      0.78      4785
#            3       0.74      0.66      0.70      2209
#            4       0.78      0.73      0.75      2839
#            5       0.83      0.86      0.84      9798
#            6       0.76      0.76      0.76      3810
#
#     accuracy                           0.80     31479
#    macro avg       0.79      0.77      0.78     31479
# weighted avg       0.80      0.80      0.80     31479

# %%
print(classification_report(test_df[target_column],svc.predict(test_X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78      2150
#            1       0.79      0.75      0.77      1809
#            2       0.78      0.71      0.74      2357
#            3       0.71      0.64      0.67      1088
#            4       0.76      0.71      0.74      1398
#            5       0.80      0.84      0.82      4827
#            6       0.72      0.73      0.72      1877
#
#     accuracy                           0.77     15506
#    macro avg       0.76      0.74      0.75     15506
# weighted avg       0.77      0.77      0.77     15506
